# %% [markdown]
# # Effects of Competition on the Illusion of Control

# %%
from dotenv import load_dotenv
load_dotenv()

import os
import numpy as np
import pandas as pd
from scipy import stats

try:
    from pandas.io.formats.style import Styler
except Exception:
    Styler = object

# %% [markdown]
# ## Сбор и подготовка данных

# %%
MODEL_ID_TO_MODEL_NAME = {
    'gpt_5_mini': 'GPT 5 Mini',
    'gpt_5_nano': 'GPT 5 Nano',
    'gpt_5': 'GPT 5',
    'deepseek_v3.2': 'DeepSeek v3.2',
    'deepseek_r1': 'DeepSeek R1',
    'grok_4_fast': 'Grok 4 Fast',
    'grok_4': 'Grok 4',
    'qwen_3_max_thinking': 'Qwen 3 Max Thinking',
    'qwen_turbo': 'Qwen Turbo',
}
MODEL_ID_TO_PROVIDER = {
    'gpt_5_mini': 'OpenAI',
    'gpt_5_nano': 'OpenAI',
    'gpt_5': 'OpenAI',
    'deepseek_v3.2': 'DeepSeek',
    'deepseek_r1': 'DeepSeek',
    'grok_4_fast': 'xAI',
    'grok_4': 'xAI',
    'qwen_3_max_thinking': 'Qwen',
    'qwen_turbo': 'Qwen',
}
MODEL_ID_TO_MODEL_TYPE = {
    'gpt_5_mini': 'Optimized',
    'gpt_5_nano': 'Optimized',
    'gpt_5': 'Normal',
    'deepseek_v3.2': 'Normal',
    'deepseek_r1': 'Thinking',
    'grok_4_fast': 'Optimized',
    'grok_4': 'Normal',
    'qwen_3_max_thinking': 'Thinking',
    'qwen_turbo': 'Optimized',
}

# %%
def join_with_dict(df, column, mapping, default='unknown', new_column=None):
    result = df.copy()
    
    mapped = result[column].map(mapping).fillna(default)
    
    if new_column is None:
        result[column] = mapped
    else:
        result[new_column] = mapped
    
    return result

# %%
competition_full_df = pd.read_csv('.' + os.environ.get('RESULTS_FOLDER') + 'competition_full/2026-04-04T11:15:28/results.csv')

# %%
competition_full_df.dtypes
# Out:
# gender           object
# model_id         object
# bet_1             int64
# bet_2             int64
# bet_3             int64
# bet_4             int64
# confidence        int64
# experiment_id    object
# variation_id     object
# condition_id     object
# iteration_id      int64
# dtype: object

# %%
competition_full_df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
competition_full_df.loc[:, 'bet_avg'] = 0.25 * (
    competition_full_df['bet_1'] + competition_full_df['bet_2'] + competition_full_df['bet_3'] + competition_full_df['bet_4'])

# %%
competition_full_df = join_with_dict(
    df=competition_full_df,
    column='model_id',
    mapping=MODEL_ID_TO_MODEL_NAME,
    default='Unknown',
    new_column='model_name'
)
competition_full_df = join_with_dict(
    df=competition_full_df,
    column='model_id',
    mapping=MODEL_ID_TO_PROVIDER,
    default='Unknown',
    new_column='provider'
)
competition_full_df = join_with_dict(
    df=competition_full_df,
    column='model_id',
    mapping=MODEL_ID_TO_MODEL_TYPE,
    default='Unknown',
    new_column='model_type'
)

# %% [markdown]
# ## Функции для аналитики

# %%
def group_function(
    group_df: pd.DataFrame,
    condition_column: str,
    condition_control: str,
    metric_columns: list[str],
) -> pd.Series:
    if condition_column not in group_df.columns:
        raise RuntimeError(f'Column {condition_column} is not found in group DataFrame.')
    if group_df[group_df[condition_column] == condition_control].empty:
        raise RuntimeError(f'Condition {condition_control} is not found in {condition_column} column.')

    result = {}

    control_df = group_df[group_df[condition_column] == condition_control]
    control_stats = {}

    for metric in metric_columns:
        n = control_df[metric].count()
        avg = control_df[metric].mean()
        std = control_df[metric].std()

        control_stats[metric] = {'n': n, 'avg': avg, 'std': std}

        result[(metric, condition_control, 'N')] = int(n)
        result[(metric, condition_control, 'Avg')] = round(avg, 1) if pd.notna(avg) else np.nan
        result[(metric, condition_control, 'Std')] = round(std, 1) if pd.notna(std) else np.nan

    for condition in group_df[condition_column].dropna().unique():
        if condition == condition_control:
            continue

        condition_df = group_df[group_df[condition_column] == condition]

        for metric in metric_columns:
            n = condition_df[metric].count()
            avg = condition_df[metric].mean()
            std = condition_df[metric].std()

            result[(metric, condition, 'N')] = int(n)
            result[(metric, condition, 'Avg')] = round(avg, 1) if pd.notna(avg) else np.nan
            result[(metric, condition, 'Std')] = round(std, 1) if pd.notna(std) else np.nan

            control_avg = control_stats[metric]['avg']
            control_std = control_stats[metric]['std']
            control_n = control_stats[metric]['n']

            diff = avg - control_avg if pd.notna(avg) and pd.notna(control_avg) else np.nan
            r_diff = 100 * (avg / control_avg - 1) if pd.notna(control_avg) and control_avg != 0 else np.nan

            if (
                pd.notna(avg)
                and pd.notna(std)
                and pd.notna(control_avg)
                and pd.notna(control_std)
                and n > 1
                and control_n > 1
            ):
                t_stat, p_value = stats.ttest_ind_from_stats(
                    mean1=avg,
                    std1=std,
                    nobs1=n,
                    mean2=control_avg,
                    std2=control_std,
                    nobs2=control_n,
                    equal_var=False,
                )
            else:
                t_stat, p_value = np.nan, np.nan

            result[(metric, condition, 'Diff')] = round(diff, 1) if pd.notna(diff) else np.nan
            result[(metric, condition, 'R. Diff')] = round(r_diff, 1) if pd.notna(r_diff) else np.nan
            result[(metric, condition, 'T-Stat')] = round(t_stat, 2) if pd.notna(t_stat) else np.nan
            result[(metric, condition, 'P-Value')] = round(p_value, 4) if pd.notna(p_value) else np.nan

    return pd.Series(result)

# %%
def _sort_metric_condition_stat_columns(
    df: pd.DataFrame,
    condition_control: str,
) -> pd.DataFrame:
    if not isinstance(df.columns, pd.MultiIndex):
        return df

    stats_order_control = ['N', 'Avg', 'Std']
    stats_order_test = ['N', 'Avg', 'Std', 'Diff', 'R. Diff', 'T-Stat', 'P-Value']

    metrics = list(dict.fromkeys(df.columns.get_level_values(0)))
    conditions = list(dict.fromkeys(df.columns.get_level_values(1)))

    ordered_cols = []

    for metric in metrics:
        if condition_control in conditions:
            for stat in stats_order_control:
                col = (metric, condition_control, stat)
                if col in df.columns:
                    ordered_cols.append(col)

        for condition in conditions:
            if condition == condition_control:
                continue
            for stat in stats_order_test:
                col = (metric, condition, stat)
                if col in df.columns:
                    ordered_cols.append(col)

    remaining = [col for col in df.columns if col not in ordered_cols]
    ordered_cols.extend(remaining)

    return df.loc[:, ordered_cols]

# %%
def calc(
    df: pd.DataFrame,
    group_columns: list[str],
    condition_column: str,
    condition_control: str,
    metric_columns: list[str],
) -> pd.DataFrame:
    result = df.groupby(by=group_columns).apply(
        lambda g_df: group_function(g_df, condition_column, condition_control, metric_columns),
        include_groups=False,
    )

    result.columns = pd.MultiIndex.from_tuples(result.columns)
    result = _sort_metric_condition_stat_columns(result, condition_control=condition_control)

    return result

# %%
def _pvalue_to_style(p_value: float, positive_effect: bool) -> str:
    if pd.isna(p_value):
        return ''

    if positive_effect:
        if p_value < 0.001:
            return 'background-color: #006d2c; color: white;'
        elif p_value < 0.01:
            return 'background-color: #31a354; color: white;'
        elif p_value < 0.05:
            return 'background-color: #74c476; color: black;'
        elif p_value < 0.10:
            return 'background-color: #c7e9c0; color: black;'
        else:
            return ''
    else:
        if p_value < 0.001:
            return 'background-color: #99000d; color: white;'
        elif p_value < 0.01:
            return 'background-color: #cb181d; color: white;'
        elif p_value < 0.05:
            return 'background-color: #fb6a4a; color: black;'
        elif p_value < 0.10:
            return 'background-color: #fcbba1; color: black;'
        else:
            return ''

# %%
def highlight_significance_gradient(
    df: pd.DataFrame,
    alpha: float = 0.10,
    stats_to_color: tuple[str, ...] = ('Diff', 'R. Diff', 'T-Stat', 'P-Value'),
    nonsig_style: str = 'background-color: #f2f2f2; color: #666666;',
) -> pd.DataFrame:
    '''
    Ожидает колонки вида: (metric, condition, stat)

    Логика:
    - p < alpha и Diff > 0  -> зеленый оттенок
    - p < alpha и Diff < 0  -> красный оттенок
    - p >= alpha            -> светло-серый
    '''
    styles = pd.DataFrame('', index=df.index, columns=df.columns)

    if not isinstance(df.columns, pd.MultiIndex):
        return styles

    metrics = df.columns.get_level_values(0).unique()
    conditions = df.columns.get_level_values(1).unique()

    for metric in metrics:
        for condition in conditions:
            p_col = (metric, condition, 'P-Value')
            diff_col = (metric, condition, 'Diff')

            if p_col not in df.columns or diff_col not in df.columns:
                continue

            for idx in df.index:
                pval = df.at[idx, p_col]
                diff = df.at[idx, diff_col]

                if pd.isna(pval) or pd.isna(diff):
                    continue

                if pval < alpha and diff != 0:
                    style = _pvalue_to_style(pval, positive_effect=(diff > 0))
                else:
                    style = nonsig_style

                for stat_name in stats_to_color:
                    col = (metric, condition, stat_name)
                    if col in df.columns:
                        styles.at[idx, col] = style

    return styles

# %%
def style_result(
    result_df: pd.DataFrame,
    alpha: float = 0.10,
):
    format_dict = {}

    for col in result_df.columns:
        stat = col[2]
        if stat == 'N':
            format_dict[col] = '{:.0f}'
        elif stat == 'Avg':
            format_dict[col] = '{:.1f}'
        elif stat == 'Std':
            format_dict[col] = '({:.1f})'
        elif stat == 'Diff':
            format_dict[col] = '{:.1f}'
        elif stat == 'R. Diff':
            format_dict[col] = '{:.1f}%'
        elif stat == 'T-Stat':
            format_dict[col] = '{:.2f}'
        elif stat == 'P-Value':
            format_dict[col] = '{:.4f}'

    table_styles = [
        {
            'selector': 'table',
            'props': [
                ('width', 'auto'),
                ('table-layout', 'auto'),
                ('border-collapse', 'collapse'),
            ],
        },
        {
            'selector': 'th',
            'props': [
                ('white-space', 'nowrap'),
                ('word-break', 'keep-all'),
                ('overflow-wrap', 'normal'),
                ('text-align', 'left'),
            ],
        },
        {
            'selector': 'td',
            'props': [
                ('white-space', 'nowrap'),
                ('word-break', 'keep-all'),
                ('overflow-wrap', 'normal'),
            ],
        },
    ]

    return (
        result_df.style
        .apply(highlight_significance_gradient, axis=None, alpha=alpha)
        .format(format_dict, na_rep='—')
        .set_table_styles(table_styles)
    )

# %% [markdown]
# ## Результаты

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'default'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence']
    )
)
# Out:
# <style type="text/css">
# #T_2d74d table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_2d74d th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_2d74d td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_2d74d_row0_col6, #T_2d74d_row0_col7, #T_2d74d_row0_col8, #T_2d74d_row0_col9, #T_2d74d_row1_col6, #T_2d74d_row1_col7, #T_2d74d_row1_col8, #T_2d74d_row1_col9, #T_2d74d_row2_col6, #T_2d74d_row2_col7, #T_2d74d_row2_col8, #T_2d74d_row2_col9, #T_2d74d_row3_col6, #T_2d74d_row3_col7, #T_2d74d_row3_col8, #T_2d74d_row3_col9, #T_2d74d_row4_col6, #T_2d74d_row4_col7, #T_2d74d_row4_col8, #T_2d74d_row4_col9, #T_2d74d_row5_col6, #T_2d74d_row5_col7, #T_2d74d_row5_col8, #T_2d74d_row5_col9, #T_2d74d_row6_col6, #T_2d74d_row6_col7, #T_2d74d_row6_col8, #T_2d74d_row6_col9, #T_2d74d_row7_col6, #T_2d74d_row7_col7, #T_2d74d_row7_col8, #T_2d74d_row7_col9, #T_2d74d_row8_col6, #T_2d74d_row8_col7, #T_2d74d_row8_col8, #T_2d74d_row8_col9 {
#   background-color: #99000d;
#   color: white;
# }
# </style>
# <table id="T_2d74d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d74d_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_2d74d_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_2d74d_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_2d74d_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_2d74d_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_2d74d_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_2d74d_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_2d74d_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_2d74d_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_2d74d_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_2d74d_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_2d74d_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_2d74d_level2_col9" class="col_heading level2 col9" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d74d_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_2d74d_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_2d74d_row0_col1" class="data row0 col1" >5.6</td>
#       <td id="T_2d74d_row0_col2" class="data row0 col2" >(0.5)</td>
#       <td id="T_2d74d_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_2d74d_row0_col4" class="data row0 col4" >2.1</td>
#       <td id="T_2d74d_row0_col5" class="data row0 col5" >(0.3)</td>
#       <td id="T_2d74d_row0_col6" class="data row0 col6" >-3.5</td>
#       <td id="T_2d74d_row0_col7" class="data row0 col7" >-62.0%</td>
#       <td id="T_2d74d_row0_col8" class="data row0 col8" >-40.72</td>
#       <td id="T_2d74d_row0_col9" class="data row0 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row1" class="row_heading level0 row1" >DeepSeek v3.2</th>
#       <td id="T_2d74d_row1_col0" class="data row1 col0" >54</td>
#       <td id="T_2d74d_row1_col1" class="data row1 col1" >5.6</td>
#       <td id="T_2d74d_row1_col2" class="data row1 col2" >(0.5)</td>
#       <td id="T_2d74d_row1_col3" class="data row1 col3" >54</td>
#       <td id="T_2d74d_row1_col4" class="data row1 col4" >2.9</td>
#       <td id="T_2d74d_row1_col5" class="data row1 col5" >(1.0)</td>
#       <td id="T_2d74d_row1_col6" class="data row1 col6" >-2.7</td>
#       <td id="T_2d74d_row1_col7" class="data row1 col7" >-48.2%</td>
#       <td id="T_2d74d_row1_col8" class="data row1 col8" >-17.16</td>
#       <td id="T_2d74d_row1_col9" class="data row1 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row2" class="row_heading level0 row2" >GPT 5</th>
#       <td id="T_2d74d_row2_col0" class="data row2 col0" >54</td>
#       <td id="T_2d74d_row2_col1" class="data row2 col1" >6.0</td>
#       <td id="T_2d74d_row2_col2" class="data row2 col2" >(0.0)</td>
#       <td id="T_2d74d_row2_col3" class="data row2 col3" >54</td>
#       <td id="T_2d74d_row2_col4" class="data row2 col4" >2.1</td>
#       <td id="T_2d74d_row2_col5" class="data row2 col5" >(0.3)</td>
#       <td id="T_2d74d_row2_col6" class="data row2 col6" >-3.9</td>
#       <td id="T_2d74d_row2_col7" class="data row2 col7" >-65.4%</td>
#       <td id="T_2d74d_row2_col8" class="data row2 col8" >-109.13</td>
#       <td id="T_2d74d_row2_col9" class="data row2 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row3" class="row_heading level0 row3" >GPT 5 Mini</th>
#       <td id="T_2d74d_row3_col0" class="data row3 col0" >54</td>
#       <td id="T_2d74d_row3_col1" class="data row3 col1" >6.0</td>
#       <td id="T_2d74d_row3_col2" class="data row3 col2" >(0.0)</td>
#       <td id="T_2d74d_row3_col3" class="data row3 col3" >54</td>
#       <td id="T_2d74d_row3_col4" class="data row3 col4" >2.0</td>
#       <td id="T_2d74d_row3_col5" class="data row3 col5" >(0.0)</td>
#       <td id="T_2d74d_row3_col6" class="data row3 col6" >-4.0</td>
#       <td id="T_2d74d_row3_col7" class="data row3 col7" >-66.7%</td>
#       <td id="T_2d74d_row3_col8" class="data row3 col8" >-inf</td>
#       <td id="T_2d74d_row3_col9" class="data row3 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row4" class="row_heading level0 row4" >GPT 5 Nano</th>
#       <td id="T_2d74d_row4_col0" class="data row4 col0" >54</td>
#       <td id="T_2d74d_row4_col1" class="data row4 col1" >5.6</td>
#       <td id="T_2d74d_row4_col2" class="data row4 col2" >(0.6)</td>
#       <td id="T_2d74d_row4_col3" class="data row4 col3" >54</td>
#       <td id="T_2d74d_row4_col4" class="data row4 col4" >2.5</td>
#       <td id="T_2d74d_row4_col5" class="data row4 col5" >(0.7)</td>
#       <td id="T_2d74d_row4_col6" class="data row4 col6" >-3.1</td>
#       <td id="T_2d74d_row4_col7" class="data row4 col7" >-55.1%</td>
#       <td id="T_2d74d_row4_col8" class="data row4 col8" >-26.40</td>
#       <td id="T_2d74d_row4_col9" class="data row4 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row5" class="row_heading level0 row5" >Grok 4</th>
#       <td id="T_2d74d_row5_col0" class="data row5 col0" >54</td>
#       <td id="T_2d74d_row5_col1" class="data row5 col1" >5.9</td>
#       <td id="T_2d74d_row5_col2" class="data row5 col2" >(0.4)</td>
#       <td id="T_2d74d_row5_col3" class="data row5 col3" >54</td>
#       <td id="T_2d74d_row5_col4" class="data row5 col4" >2.0</td>
#       <td id="T_2d74d_row5_col5" class="data row5 col5" >(0.2)</td>
#       <td id="T_2d74d_row5_col6" class="data row5 col6" >-3.8</td>
#       <td id="T_2d74d_row5_col7" class="data row5 col7" >-65.2%</td>
#       <td id="T_2d74d_row5_col8" class="data row5 col8" >-69.03</td>
#       <td id="T_2d74d_row5_col9" class="data row5 col9" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d74d_level0_row6" class="row_heading level0 row6" >Grok 4 Fast</th>
#       <td id="T_2d74d_row6_col0" class="data row6 col0" >54</td>
#       <td id="T_2d74d_row6_col1" class="data row6 col1" >6.0</td>
#       <td id="T_2d74d_row6_col2" class="data row6 col2" >(0.1)</td>
#       <td id="T_2d74d_row6_col3" class="data row6 col3" >54</td>
#       <td id="T_2d74d_row6_col4" class="data row6 col4" >1.8</td>
#       <td id="T_2d74d_row6_col5" class="data row6 col5" >(0.

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'default'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_157dc table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_157dc th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_157dc td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_157dc_row0_col6, #T_157dc_row0_col7, #T_157dc_row0_col8, #T_157dc_row0_col9, #T_157dc_row0_col16, #T_157dc_row0_col17, #T_157dc_row0_col18, #T_157dc_row0_col19 {
#   background-color: #74c476;
#   color: black;
# }
# #T_157dc_row1_col6, #T_157dc_row1_col7, #T_157dc_row1_col8, #T_157dc_row1_col9, #T_157dc_row1_col16, #T_157dc_row1_col17, #T_157dc_row1_col18, #T_157dc_row1_col19, #T_157dc_row2_col6, #T_157dc_row2_col7, #T_157dc_row2_col8, #T_157dc_row2_col9, #T_157dc_row4_col6, #T_157dc_row4_col7, #T_157dc_row4_col8, #T_157dc_row4_col9, #T_157dc_row4_col16, #T_157dc_row4_col17, #T_157dc_row4_col18, #T_157dc_row4_col19, #T_157dc_row6_col16, #T_157dc_row6_col17, #T_157dc_row6_col18, #T_157dc_row6_col19 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_157dc_row2_col16, #T_157dc_row2_col17, #T_157dc_row2_col18, #T_157dc_row2_col19, #T_157dc_row5_col16, #T_157dc_row5_col17, #T_157dc_row5_col18, #T_157dc_row5_col19 {
#   background-color: #fb6a4a;
#   color: black;
# }
# #T_157dc_row3_col6, #T_157dc_row3_col7, #T_157dc_row3_col8, #T_157dc_row3_col9, #T_157dc_row3_col16, #T_157dc_row3_col17, #T_157dc_row3_col18, #T_157dc_row3_col19, #T_157dc_row6_col6, #T_157dc_row6_col7, #T_157dc_row6_col8, #T_157dc_row6_col9, #T_157dc_row7_col6, #T_157dc_row7_col7, #T_157dc_row7_col8, #T_157dc_row7_col9, #T_157dc_row7_col16, #T_157dc_row7_col17, #T_157dc_row7_col18, #T_157dc_row7_col19 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_157dc_row5_col6, #T_157dc_row5_col7, #T_157dc_row5_col8, #T_157dc_row5_col9 {
#   background-color: #fcbba1;
#   color: black;
# }
# </style>
# <table id="T_157dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_157dc_level0_col0" class="col_heading level0 col0" colspan="10">bet_1</th>
#       <th id="T_157dc_level0_col10" class="col_heading level0 col10" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_157dc_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_157dc_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_157dc_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_157dc_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_157dc_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_157dc_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_157dc_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_157dc_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_157dc_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_157dc_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_157dc_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_157dc_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_157dc_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_157dc_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_157dc_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_157dc_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_157dc_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_157dc_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_157dc_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_157dc_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_157dc_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_157dc_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_157dc_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_157dc_level2_col19" class="col_heading level2 col19" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_157dc_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_157dc_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_157dc_row0_col1" class="data row0 col1" >12.4</td>
#       <td id="T_157dc_row0_col2" class="data row0 col2" >(3.0)</td>
#       <td id="T_157dc_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_157dc_row0_col4" class="data row0 col4" >13.8</td>
#       <td id="T_157dc_row0_col5" class="data row0 col5" >(3.2)</td>
#       <td id="T_157dc_row0_col6" class="data row0 col6" >1.4</td>
#       <td id="T_157dc_row0_col7" class="data row0 col7" >11.1%</td>
#       <td id="T_157dc_row0_col8" class="data row0 col8" >2.31</td>
#       <td id="T_157dc_row0_col9" class="data row0 col9" >0.0231</td>
#       <td id="T_157dc_row0_col10" class="data row0 col10" >54</td>
#       <td id="T_157dc_row0_col11" class="data row0 col11" >13.9</td>
#       <td id="T_157dc_row0_col12" class="data row0 col12" >(4.8)</td>
#       <td id="T_157dc_row0_col13" class="data row0 col13" >54</td>
#       <td id="T_157dc_row0_col14" class="data row0 col14" >16.0</td>
#       <td id="T_157dc_row0_col15" class="data row0 col15" >(4.8)</td>
#       <td id="T_157dc_row0_col16" class="data row0 col16" >2.1</td>
#       <td id="T_157dc_row0_col17" class="data row0 col17" >15.0%</td>
#       <td id="T_157dc_row0_col18" class="data row0 col18" >2.26</td>
#       <td id="T_157dc_row0_col19" class="data row0 col19" >0.0261</td>
#     </tr>
#     <tr>
#       <th id="T_157dc_level0_row1" class="row_heading level0 row1" >DeepSeek v3.2</th>
#       <td id="T_157dc_row1_col0" class="data row1 col0" >54</td>
#       <td id="T_157dc_row1_col1" class="data row1 col1" >10.0</td>
#       <td id="T_157dc_row1_col2" class="data row1 col2" >(6.2)</td>
#       <td id="T_157dc_row1_col3" class="data row1 col3" >54</td>
#       <td id="T_157dc_row1_col4" class="data row1 col4" >11.0</td>
#       <td id="T_157dc_row1_col5" class="data row1 col5" >(7.8)</td>
#       <td id="T_157dc_row1_col6" class="data row1 col6" >1.1</td>
#       <td id="T_157dc_row1_col7" class="data row1 col7" >10.6%</td>
#       <td id="T_157dc_row1_col8" class="data row1 col8" >0.78</td>
#       <td id="T_157dc_row1_col9" class="data row1 col9" >0.4382</td>
#       <td id="T_157dc_row1_col10" class="data row1 col10" >54</td>
#       <td id="T_157dc_row1_col11" class="data row1 col11" >13.2</td>
#       <td id="T_157dc_row1_col12" class="data row1 col12" >(3.0)</td>
#       <td id="T_157dc_row1_col13" class="data row1 col13" >54</td>
#       <td id="T_157dc_row1_col14" class="data row1 col14" >13.7</td>
#       <td id="T_157dc_row1_col15" class="data row1 col15" >(3.7)</td>
#       <td id="T_157dc_row1_col16" class="data row1 col16" >0.5</td>
#       <td id="T_157dc_row1_col17" class="data row1 col17" >3.5%</td>
#       <td id="T_157dc_row1_col18" class="data row1 col18"

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'default'],
        group_columns=['model_type'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_d136d table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_d136d th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_d136d td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_d136d_row0_col6, #T_d136d_row0_col7, #T_d136d_row0_col8, #T_d136d_row0_col9, #T_d136d_row1_col6, #T_d136d_row1_col7, #T_d136d_row1_col8, #T_d136d_row1_col9, #T_d136d_row2_col6, #T_d136d_row2_col7, #T_d136d_row2_col8, #T_d136d_row2_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_d136d_row0_col16, #T_d136d_row0_col17, #T_d136d_row0_col18, #T_d136d_row0_col19, #T_d136d_row0_col26, #T_d136d_row0_col27, #T_d136d_row0_col28, #T_d136d_row0_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_d136d_row1_col16, #T_d136d_row1_col17, #T_d136d_row1_col18, #T_d136d_row1_col19 {
#   background-color: #31a354;
#   color: white;
# }
# #T_d136d_row1_col26, #T_d136d_row1_col27, #T_d136d_row1_col28, #T_d136d_row1_col29 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_d136d_row2_col16, #T_d136d_row2_col17, #T_d136d_row2_col18, #T_d136d_row2_col19, #T_d136d_row2_col26, #T_d136d_row2_col27, #T_d136d_row2_col28, #T_d136d_row2_col29 {
#   background-color: #006d2c;
#   color: white;
# }
# </style>
# <table id="T_d136d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d136d_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_d136d_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_d136d_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_d136d_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_d136d_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_d136d_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_d136d_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_d136d_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_d136d_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_d136d_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_d136d_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_d136d_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_d136d_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_d136d_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_d136d_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_d136d_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_d136d_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_d136d_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_d136d_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_d136d_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_d136d_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_d136d_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_d136d_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_d136d_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_d136d_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_d136d_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_d136d_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_d136d_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_d136d_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_d136d_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_d136d_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_d136d_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_d136d_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_d136d_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_d136d_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_d136d_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_d136d_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_d136d_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_d136d_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d136d_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_d136d_row0_col0" class="data row0 col0" >162</td>
#       <td id="T_d136d_row0_col1" class="data row0 col1" >5.8</td>
#       <td id="T_d136d_row0_col2" class="data row0 col2" >(0.4)</td>
#       <td id="T_d136d_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_d136d_row0_col4" class="data row0 col4" >2.3</td>
#       <td id="T_d136d_row0_col5" class="data row0 col5" >(0.8)</td>
#       <td id="T_d136d_row0_col6" class="data row0 col6" >-3.5</td>
#       <td id="T_d136d_row0_col7" class="data row0 col7" >-59.8%</td>
#       <td id="T_d136d_row0_col8" class="data row0 col8" >-52.49</td>
#       <td id="T_d136d_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_d136d_row0_col10" class="data row0 col10" >162</td>
#       <td id="T_d136d_row0_col11" class="data row0 col11" >12.8</td>
#       <td id="T_d136d_row0_col12" class="data row0 col12" >(5.3)</td>
#       <td id="T_d136d_row0_col13" class="data row0 col13" >162</td>
#       <td id="T_d136d_row0_col14" class="data row0 col14" >12.5</td>
#       <td id="T_d136d_row0_col15" class="data row0 col15" >(5.6)</td>
#       <td id="T_d136d_row0_col16" class="data row0 col16" >-0.3</td>
#       <td id="T_d136d_row0_col17" class="data row0 col17" >-2.3%</td>
#       <td id="T_d136d_row0_col18" class="data row0 col18" >-0.49</td>
#       <td id="T_d136d_row0_col19" class="data row0 col19" >0.6233</td>
#       <td id="T_d136d_row0_col20" class="data row0 col20" >162</td>
#       <td id="T_d136d_row0_col21" class="data row0 col21" >17.3</td>
#       <td id="T_d136d_row0_col22" class="data row0 col22" >(4.1)</td>
#       <td id="T_d136d_row0_col23" class="data row0 col23" >162</td>
#       <td id="T_d136d_row0_col24" class="data row0 col24" >16.6</td>
#       <td id="T_d136d_row0_col25" class="data row0 col25" >(4.0)</td>
#       <td id="T_d136d

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'higher_emphasis'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_65b08 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_65b08 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_65b08 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_65b08_row0_col6, #T_65b08_row0_col7, #T_65b08_row0_col8, #T_65b08_row0_col9, #T_65b08_row1_col6, #T_65b08_row1_col7, #T_65b08_row1_col8, #T_65b08_row1_col9, #T_65b08_row2_col6, #T_65b08_row2_col7, #T_65b08_row2_col8, #T_65b08_row2_col9, #T_65b08_row3_col6, #T_65b08_row3_col7, #T_65b08_row3_col8, #T_65b08_row3_col9, #T_65b08_row4_col6, #T_65b08_row4_col7, #T_65b08_row4_col8, #T_65b08_row4_col9, #T_65b08_row5_col6, #T_65b08_row5_col7, #T_65b08_row5_col8, #T_65b08_row5_col9, #T_65b08_row6_col6, #T_65b08_row6_col7, #T_65b08_row6_col8, #T_65b08_row6_col9, #T_65b08_row7_col6, #T_65b08_row7_col7, #T_65b08_row7_col8, #T_65b08_row7_col9, #T_65b08_row8_col6, #T_65b08_row8_col7, #T_65b08_row8_col8, #T_65b08_row8_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_65b08_row0_col16, #T_65b08_row0_col17, #T_65b08_row0_col18, #T_65b08_row0_col19 {
#   background-color: #31a354;
#   color: white;
# }
# #T_65b08_row0_col26, #T_65b08_row0_col27, #T_65b08_row0_col28, #T_65b08_row0_col29, #T_65b08_row1_col16, #T_65b08_row1_col17, #T_65b08_row1_col18, #T_65b08_row1_col19, #T_65b08_row2_col26, #T_65b08_row2_col27, #T_65b08_row2_col28, #T_65b08_row2_col29, #T_65b08_row4_col26, #T_65b08_row4_col27, #T_65b08_row4_col28, #T_65b08_row4_col29, #T_65b08_row5_col26, #T_65b08_row5_col27, #T_65b08_row5_col28, #T_65b08_row5_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_65b08_row1_col26, #T_65b08_row1_col27, #T_65b08_row1_col28, #T_65b08_row1_col29, #T_65b08_row3_col16, #T_65b08_row3_col17, #T_65b08_row3_col18, #T_65b08_row3_col19, #T_65b08_row3_col26, #T_65b08_row3_col27, #T_65b08_row3_col28, #T_65b08_row3_col29, #T_65b08_row4_col16, #T_65b08_row4_col17, #T_65b08_row4_col18, #T_65b08_row4_col19, #T_65b08_row6_col16, #T_65b08_row6_col17, #T_65b08_row6_col18, #T_65b08_row6_col19, #T_65b08_row7_col16, #T_65b08_row7_col17, #T_65b08_row7_col18, #T_65b08_row7_col19, #T_65b08_row7_col26, #T_65b08_row7_col27, #T_65b08_row7_col28, #T_65b08_row7_col29 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_65b08_row2_col16, #T_65b08_row2_col17, #T_65b08_row2_col18, #T_65b08_row2_col19, #T_65b08_row6_col26, #T_65b08_row6_col27, #T_65b08_row6_col28, #T_65b08_row6_col29 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_65b08_row5_col16, #T_65b08_row5_col17, #T_65b08_row5_col18, #T_65b08_row5_col19 {
#   background-color: #fb6a4a;
#   color: black;
# }
# </style>
# <table id="T_65b08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65b08_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_65b08_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_65b08_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_65b08_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_65b08_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_65b08_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_65b08_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_65b08_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_65b08_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_65b08_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_65b08_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_65b08_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_65b08_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_65b08_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_65b08_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_65b08_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_65b08_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_65b08_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_65b08_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_65b08_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_65b08_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_65b08_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_65b08_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_65b08_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_65b08_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_65b08_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_65b08_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_65b08_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_65b08_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_65b08_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_65b08_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_65b08_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_65b08_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_65b08_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_65b08_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_65b08_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_65b08_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_65b08_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_65b08_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65b08_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_65b08_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_65b08_row0_col1" class="data row0 col1" >5.5</td>
#       <td id="T_65b08_row0_col2" class="data row0 col2" >(0.6)</td>
#       <td id="T_65b08_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_65b08_row0_col4" class="data row0 col4" >2.1</td>
#       <td id="T_65b08_row0_col5" class="data row0 col5" >(0.5)</td>
#       <td id="T_65b08_row0_col6"

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'higher_emphasis'],
        group_columns=['model_type'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_a58b3 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_a58b3 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_a58b3 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_a58b3_row0_col6, #T_a58b3_row0_col7, #T_a58b3_row0_col8, #T_a58b3_row0_col9, #T_a58b3_row1_col6, #T_a58b3_row1_col7, #T_a58b3_row1_col8, #T_a58b3_row1_col9, #T_a58b3_row2_col6, #T_a58b3_row2_col7, #T_a58b3_row2_col8, #T_a58b3_row2_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_a58b3_row0_col16, #T_a58b3_row0_col17, #T_a58b3_row0_col18, #T_a58b3_row0_col19 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_a58b3_row0_col26, #T_a58b3_row0_col27, #T_a58b3_row0_col28, #T_a58b3_row0_col29 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_a58b3_row1_col16, #T_a58b3_row1_col17, #T_a58b3_row1_col18, #T_a58b3_row1_col19, #T_a58b3_row1_col26, #T_a58b3_row1_col27, #T_a58b3_row1_col28, #T_a58b3_row1_col29, #T_a58b3_row2_col16, #T_a58b3_row2_col17, #T_a58b3_row2_col18, #T_a58b3_row2_col19, #T_a58b3_row2_col26, #T_a58b3_row2_col27, #T_a58b3_row2_col28, #T_a58b3_row2_col29 {
#   background-color: #006d2c;
#   color: white;
# }
# </style>
# <table id="T_a58b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a58b3_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_a58b3_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_a58b3_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a58b3_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_a58b3_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_a58b3_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_a58b3_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_a58b3_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_a58b3_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_a58b3_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_a58b3_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_a58b3_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_a58b3_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_a58b3_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_a58b3_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_a58b3_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_a58b3_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_a58b3_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_a58b3_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_a58b3_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_a58b3_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_a58b3_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_a58b3_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_a58b3_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_a58b3_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_a58b3_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_a58b3_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_a58b3_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_a58b3_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_a58b3_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_a58b3_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_a58b3_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_a58b3_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_a58b3_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_a58b3_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_a58b3_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_a58b3_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_a58b3_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_a58b3_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a58b3_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_a58b3_row0_col0" class="data row0 col0" >162</td>
#       <td id="T_a58b3_row0_col1" class="data row0 col1" >5.9</td>
#       <td id="T_a58b3_row0_col2" class="data row0 col2" >(0.4)</td>
#       <td id="T_a58b3_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_a58b3_row0_col4" class="data row0 col4" >2.3</td>
#       <td id="T_a58b3_row0_col5" class="data row0 col5" >(0.9)</td>
#       <td id="T_a58b3_row0_col6" class="data row0 col6" >-3.5</td>
#       <td id="T_a58b3_row0_col7" class="data row0 col7" >-60.3%</td>
#       <td id="T_a58b3_row0_col8" class="data row0 col8" >-49.09</td>
#       <td id="T_a58b3_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_a58b3_row0_col10" class="data row0 col10" >162</td>
#       <td id="T_a58b3_row0_col11" class="data row0 col11" >12.5</td>
#       <td id="T_a58b3_row0_col12" class="data row0 col12" >(5.8)</td>
#       <td id="T_a58b3_row0_col13" class="data row0 col13" >162</td>
#       <td id="T_a58b3_row0_col14" class="data row0 col14" >12.6</td>
#       <td id="T_a58b3_row0_col15" class="data row0 col15" >(5.0)</td>
#       <td id="T_a58b3_row0_col16" class="data row0 col16" >0.1</td>
#       <td id="T_a58b3_row0_col17" class="data row0 col17" >0.7%</td>
#       <td id="T_a58b3_row0_col18" class="data row0 col18" >0.14</td>
#       <td id="T_a58b3_row0_col19" class="data row0 col19" >0.8861</td>
#       <td id="T_a58b3_row0_col20" class="data row0 col20" >162</td>
#       <td id="T_a58b3_row0_col21" class="data row0 col21" >16.0</td>
#       <td id="T_a58b3_row0_col22" class="data row0 col22" >(5.4)</td>
#       <td id="T_a58b3_row0_col23" class="data row0 col23" >162</td>
#       <td id="T_a58b3_row0_col24" class="data row0 col24" >17.0</td>
#       <td id="T_a58b3_row0_col25" class="data row0 col25" >(3.8)</td>
#       <td id="T_a58b3_row0_col26" class="data row0 col26" >1.0</td>

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'lower_emphasis'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_9bb54 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_9bb54 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_9bb54 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_9bb54_row0_col6, #T_9bb54_row0_col7, #T_9bb54_row0_col8, #T_9bb54_row0_col9, #T_9bb54_row1_col6, #T_9bb54_row1_col7, #T_9bb54_row1_col8, #T_9bb54_row1_col9, #T_9bb54_row2_col6, #T_9bb54_row2_col7, #T_9bb54_row2_col8, #T_9bb54_row2_col9, #T_9bb54_row3_col6, #T_9bb54_row3_col7, #T_9bb54_row3_col8, #T_9bb54_row3_col9, #T_9bb54_row4_col6, #T_9bb54_row4_col7, #T_9bb54_row4_col8, #T_9bb54_row4_col9, #T_9bb54_row5_col6, #T_9bb54_row5_col7, #T_9bb54_row5_col8, #T_9bb54_row5_col9, #T_9bb54_row6_col6, #T_9bb54_row6_col7, #T_9bb54_row6_col8, #T_9bb54_row6_col9, #T_9bb54_row7_col6, #T_9bb54_row7_col7, #T_9bb54_row7_col8, #T_9bb54_row7_col9, #T_9bb54_row8_col6, #T_9bb54_row8_col7, #T_9bb54_row8_col8, #T_9bb54_row8_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_9bb54_row0_col16, #T_9bb54_row0_col17, #T_9bb54_row0_col18, #T_9bb54_row0_col19, #T_9bb54_row6_col16, #T_9bb54_row6_col17, #T_9bb54_row6_col18, #T_9bb54_row6_col19 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_9bb54_row0_col26, #T_9bb54_row0_col27, #T_9bb54_row0_col28, #T_9bb54_row0_col29, #T_9bb54_row2_col16, #T_9bb54_row2_col17, #T_9bb54_row2_col18, #T_9bb54_row2_col19, #T_9bb54_row2_col26, #T_9bb54_row2_col27, #T_9bb54_row2_col28, #T_9bb54_row2_col29, #T_9bb54_row4_col16, #T_9bb54_row4_col17, #T_9bb54_row4_col18, #T_9bb54_row4_col19, #T_9bb54_row4_col26, #T_9bb54_row4_col27, #T_9bb54_row4_col28, #T_9bb54_row4_col29, #T_9bb54_row5_col16, #T_9bb54_row5_col17, #T_9bb54_row5_col18, #T_9bb54_row5_col19, #T_9bb54_row6_col26, #T_9bb54_row6_col27, #T_9bb54_row6_col28, #T_9bb54_row6_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_9bb54_row1_col16, #T_9bb54_row1_col17, #T_9bb54_row1_col18, #T_9bb54_row1_col19, #T_9bb54_row3_col16, #T_9bb54_row3_col17, #T_9bb54_row3_col18, #T_9bb54_row3_col19, #T_9bb54_row7_col16, #T_9bb54_row7_col17, #T_9bb54_row7_col18, #T_9bb54_row7_col19 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_9bb54_row1_col26, #T_9bb54_row1_col27, #T_9bb54_row1_col28, #T_9bb54_row1_col29, #T_9bb54_row3_col26, #T_9bb54_row3_col27, #T_9bb54_row3_col28, #T_9bb54_row3_col29, #T_9bb54_row5_col26, #T_9bb54_row5_col27, #T_9bb54_row5_col28, #T_9bb54_row5_col29, #T_9bb54_row7_col26, #T_9bb54_row7_col27, #T_9bb54_row7_col28, #T_9bb54_row7_col29 {
#   background-color: #74c476;
#   color: black;
# }
# </style>
# <table id="T_9bb54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bb54_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_9bb54_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_9bb54_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_9bb54_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_9bb54_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_9bb54_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_9bb54_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_9bb54_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_9bb54_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_9bb54_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_9bb54_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_9bb54_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_9bb54_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_9bb54_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_9bb54_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_9bb54_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_9bb54_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_9bb54_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_9bb54_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_9bb54_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_9bb54_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_9bb54_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_9bb54_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_9bb54_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_9bb54_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_9bb54_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_9bb54_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_9bb54_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_9bb54_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_9bb54_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_9bb54_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_9bb54_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_9bb54_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_9bb54_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_9bb54_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_9bb54_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_9bb54_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_9bb54_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_9bb54_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bb54_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_9bb54_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_9bb54_row0_col1" class="data row0 col1" >5.0</td>
#       <td id="T_9bb54_row0_col2" class="data row0 col2" >(0.4)</td>
#       <td id="T_9bb54_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_9bb54_row0_col4" class="data row0 col4" >2.9</td>
#       <td id="T_9bb54_row0_col5" class="data row0 col5" >(0.6)</td>
#       <td id="T_9bb54_row0_col6" class="data row0 col6" >-2.2</td>
#       <td id=

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'lower_emphasis'],
        group_columns=['model_type'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_89727 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_89727 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_89727 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_89727_row0_col6, #T_89727_row0_col7, #T_89727_row0_col8, #T_89727_row0_col9, #T_89727_row1_col6, #T_89727_row1_col7, #T_89727_row1_col8, #T_89727_row1_col9, #T_89727_row2_col6, #T_89727_row2_col7, #T_89727_row2_col8, #T_89727_row2_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_89727_row0_col16, #T_89727_row0_col17, #T_89727_row0_col18, #T_89727_row0_col19 {
#   background-color: #31a354;
#   color: white;
# }
# #T_89727_row0_col26, #T_89727_row0_col27, #T_89727_row0_col28, #T_89727_row0_col29 {
#   background-color: #74c476;
#   color: black;
# }
# #T_89727_row1_col16, #T_89727_row1_col17, #T_89727_row1_col18, #T_89727_row1_col19 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_89727_row1_col26, #T_89727_row1_col27, #T_89727_row1_col28, #T_89727_row1_col29, #T_89727_row2_col26, #T_89727_row2_col27, #T_89727_row2_col28, #T_89727_row2_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_89727_row2_col16, #T_89727_row2_col17, #T_89727_row2_col18, #T_89727_row2_col19 {
#   background-color: #006d2c;
#   color: white;
# }
# </style>
# <table id="T_89727">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89727_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_89727_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_89727_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_89727_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_89727_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_89727_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_89727_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_89727_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_89727_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_89727_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_89727_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_89727_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_89727_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_89727_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_89727_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_89727_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_89727_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_89727_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_89727_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_89727_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_89727_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_89727_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_89727_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_89727_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_89727_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_89727_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_89727_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_89727_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_89727_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_89727_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_89727_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_89727_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_89727_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_89727_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_89727_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_89727_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_89727_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_89727_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_89727_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89727_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_89727_row0_col0" class="data row0 col0" >162</td>
#       <td id="T_89727_row0_col1" class="data row0 col1" >5.1</td>
#       <td id="T_89727_row0_col2" class="data row0 col2" >(0.6)</td>
#       <td id="T_89727_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_89727_row0_col4" class="data row0 col4" >3.3</td>
#       <td id="T_89727_row0_col5" class="data row0 col5" >(0.9)</td>
#       <td id="T_89727_row0_col6" class="data row0 col6" >-1.8</td>
#       <td id="T_89727_row0_col7" class="data row0 col7" >-35.5%</td>
#       <td id="T_89727_row0_col8" class="data row0 col8" >-21.51</td>
#       <td id="T_89727_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_89727_row0_col10" class="data row0 col10" >162</td>
#       <td id="T_89727_row0_col11" class="data row0 col11" >11.2</td>
#       <td id="T_89727_row0_col12" class="data row0 col12" >(5.1)</td>
#       <td id="T_89727_row0_col13" class="data row0 col13" >162</td>
#       <td id="T_89727_row0_col14" class="data row0 col14" >12.8</td>
#       <td id="T_89727_row0_col15" class="data row0 col15" >(4.7)</td>
#       <td id="T_89727_row0_col16" class="data row0 col16" >1.6</td>
#       <td id="T_89727_row0_col17" class="data row0 col17" >14.4%</td>
#       <td id="T_89727_row0_col18" class="data row0 col18" >2.95</td>
#       <td id="T_89727_row0_col19" class="data row0 col19" >0.0034</td>
#       <td id="T_89727_row0_col20" class="data row0 col20" >162</td>
#       <td id="T_89727_row0_col21" class="data row0 col21" >15.4</td>
#       <td id="T_89727_row0_col22" class="data row0 col22" >(4.6)</td>
#       <td id="T_89727_row0_col23" class="data row0 col23" >162</td>
#       <td id="T_89727_row0_col24" class="data row0 col24" >16.4</td>
#       <td id="T_89727_row0_col25" class="data

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'without_emphasis'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_d9240 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_d9240 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_d9240 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_d9240_row0_col6, #T_d9240_row0_col7, #T_d9240_row0_col8, #T_d9240_row0_col9, #T_d9240_row0_col16, #T_d9240_row0_col17, #T_d9240_row0_col18, #T_d9240_row0_col19, #T_d9240_row0_col26, #T_d9240_row0_col27, #T_d9240_row0_col28, #T_d9240_row0_col29, #T_d9240_row1_col6, #T_d9240_row1_col7, #T_d9240_row1_col8, #T_d9240_row1_col9, #T_d9240_row1_col16, #T_d9240_row1_col17, #T_d9240_row1_col18, #T_d9240_row1_col19, #T_d9240_row1_col26, #T_d9240_row1_col27, #T_d9240_row1_col28, #T_d9240_row1_col29, #T_d9240_row2_col6, #T_d9240_row2_col7, #T_d9240_row2_col8, #T_d9240_row2_col9, #T_d9240_row2_col16, #T_d9240_row2_col17, #T_d9240_row2_col18, #T_d9240_row2_col19, #T_d9240_row2_col26, #T_d9240_row2_col27, #T_d9240_row2_col28, #T_d9240_row2_col29, #T_d9240_row3_col6, #T_d9240_row3_col7, #T_d9240_row3_col8, #T_d9240_row3_col9, #T_d9240_row3_col16, #T_d9240_row3_col17, #T_d9240_row3_col18, #T_d9240_row3_col19, #T_d9240_row3_col26, #T_d9240_row3_col27, #T_d9240_row3_col28, #T_d9240_row3_col29, #T_d9240_row4_col6, #T_d9240_row4_col7, #T_d9240_row4_col8, #T_d9240_row4_col9, #T_d9240_row4_col16, #T_d9240_row4_col17, #T_d9240_row4_col18, #T_d9240_row4_col19, #T_d9240_row4_col26, #T_d9240_row4_col27, #T_d9240_row4_col28, #T_d9240_row4_col29, #T_d9240_row5_col6, #T_d9240_row5_col7, #T_d9240_row5_col8, #T_d9240_row5_col9, #T_d9240_row5_col16, #T_d9240_row5_col17, #T_d9240_row5_col18, #T_d9240_row5_col19, #T_d9240_row5_col26, #T_d9240_row5_col27, #T_d9240_row5_col28, #T_d9240_row5_col29, #T_d9240_row6_col16, #T_d9240_row6_col17, #T_d9240_row6_col18, #T_d9240_row6_col19, #T_d9240_row6_col26, #T_d9240_row6_col27, #T_d9240_row6_col28, #T_d9240_row6_col29, #T_d9240_row7_col6, #T_d9240_row7_col7, #T_d9240_row7_col8, #T_d9240_row7_col9, #T_d9240_row7_col16, #T_d9240_row7_col17, #T_d9240_row7_col18, #T_d9240_row7_col19, #T_d9240_row7_col26, #T_d9240_row7_col27, #T_d9240_row7_col28, #T_d9240_row7_col29, #T_d9240_row8_col6, #T_d9240_row8_col7, #T_d9240_row8_col8, #T_d9240_row8_col9 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_d9240_row6_col6, #T_d9240_row6_col7, #T_d9240_row6_col8, #T_d9240_row6_col9 {
#   background-color: #c7e9c0;
#   color: black;
# }
# </style>
# <table id="T_d9240">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9240_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_d9240_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_d9240_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_d9240_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_d9240_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_d9240_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_d9240_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_d9240_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_d9240_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_d9240_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_d9240_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_d9240_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_d9240_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_d9240_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_d9240_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_d9240_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_d9240_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_d9240_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_d9240_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_d9240_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_d9240_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_d9240_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_d9240_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_d9240_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_d9240_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_d9240_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_d9240_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_d9240_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_d9240_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_d9240_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_d9240_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_d9240_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_d9240_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_d9240_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_d9240_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_d9240_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_d9240_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_d9240_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_d9240_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9240_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_d9240_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_d9240_row0_col1" class="data row0 col1" >3.8</td>
#       <td id="T_d9240_row0_col2" class="data row0 col2" >(0.6)</td>
#       <td id="T_d9240_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_d9240_row0_col4" class="data row0 col4" >3.8</td>
#       <td id="T_d9240_row0_col5" class="data row0 col5" >(0.5)</td>
#       <td id="T_d9240_row0_col6" class="data row0 col6" >-0.0</td>
#       <td id="T_d9240_row0_col7" class="data row0 col7" >-0.5%</td>
#       <td id="T_d9240_row0_col8" class="data row0 col8" >-0.17</td>
#       <td id="T_d9240

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'without_emphasis'],
        group_columns=['model_type'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_322a3 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_322a3 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_322a3 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_322a3_row0_col6, #T_322a3_row0_col7, #T_322a3_row0_col8, #T_322a3_row0_col9, #T_322a3_row0_col16, #T_322a3_row0_col17, #T_322a3_row0_col18, #T_322a3_row0_col19, #T_322a3_row0_col26, #T_322a3_row0_col27, #T_322a3_row0_col28, #T_322a3_row0_col29, #T_322a3_row1_col6, #T_322a3_row1_col7, #T_322a3_row1_col8, #T_322a3_row1_col9, #T_322a3_row1_col16, #T_322a3_row1_col17, #T_322a3_row1_col18, #T_322a3_row1_col19, #T_322a3_row1_col26, #T_322a3_row1_col27, #T_322a3_row1_col28, #T_322a3_row1_col29, #T_322a3_row2_col6, #T_322a3_row2_col7, #T_322a3_row2_col8, #T_322a3_row2_col9, #T_322a3_row2_col16, #T_322a3_row2_col17, #T_322a3_row2_col18, #T_322a3_row2_col19, #T_322a3_row2_col26, #T_322a3_row2_col27, #T_322a3_row2_col28, #T_322a3_row2_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# </style>
# <table id="T_322a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_322a3_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_322a3_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_322a3_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_322a3_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_322a3_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_322a3_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_322a3_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_322a3_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_322a3_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_322a3_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_322a3_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_322a3_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_322a3_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_322a3_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_322a3_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_322a3_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_322a3_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_322a3_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_322a3_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_322a3_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_322a3_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_322a3_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_322a3_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_322a3_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_322a3_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_322a3_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_322a3_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_322a3_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_322a3_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_322a3_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_322a3_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_322a3_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_322a3_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_322a3_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_322a3_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_322a3_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_322a3_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_322a3_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_322a3_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_322a3_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_322a3_row0_col0" class="data row0 col0" >162</td>
#       <td id="T_322a3_row0_col1" class="data row0 col1" >4.2</td>
#       <td id="T_322a3_row0_col2" class="data row0 col2" >(0.7)</td>
#       <td id="T_322a3_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_322a3_row0_col4" class="data row0 col4" >4.3</td>
#       <td id="T_322a3_row0_col5" class="data row0 col5" >(0.6)</td>
#       <td id="T_322a3_row0_col6" class="data row0 col6" >0.1</td>
#       <td id="T_322a3_row0_col7" class="data row0 col7" >2.4%</td>
#       <td id="T_322a3_row0_col8" class="data row0 col8" >1.29</td>
#       <td id="T_322a3_row0_col9" class="data row0 col9" >0.1981</td>
#       <td id="T_322a3_row0_col10" class="data row0 col10" >162</td>
#       <td id="T_322a3_row0_col11" class="data row0 col11" >13.0</td>
#       <td id="T_322a3_row0_col12" class="data row0 col12" >(5.1)</td>
#       <td id="T_322a3_row0_col13" class="data row0 col13" >162</td>
#       <td id="T_322a3_row0_col14" class="data row0 col14" >13.0</td>
#       <td id="T_322a3_row0_col15" class="data row0 col15" >(5.3)</td>
#       <td id="T_322a3_row0_col16" class="data row0 col16" >0.0</td>
#       <td id="T_322a3_row0_col17" class="data row0 col17" >0.0%</td>
#       <td id="T_322a3_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_322a3_row0_col19" class="data row0 col19" >1.0000</td>
#       <td id="T_322a3_row0_col20" class="data row0 col20" >162</td>
#       <td id="T_322a3_row0_col21" class="data row0 col21" >16.9</td>
#       <td id="T_322a3_row0_col22" class="data row0 col22" >(3.5)</td>
#       <td id="T_322a3_row0_col23" class="data row0 col23" >162</td>
#       <td id="T_322a3_row0_col24" class="data row0 col24" >16.9</td>
#       <td id="T_322a3_row0_col25" class="data row0 col25" >(3.6)</td>
#       <td id="T_322a3_row0_col26" class="data row0 col26" >-0.0</td>
#       <td id="T_322a3_row0_col27" class="data row0 col27" >-0.1%</td>
#       <td id="T_322a3_row0_col28" class="data row0 col28" >-0.03</td>
#       <td id

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'fully_rational'],
        group_columns=['model_name'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_9afa4 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_9afa4 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_9afa4 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_9afa4_row0_col6, #T_9afa4_row0_col7, #T_9afa4_row0_col8, #T_9afa4_row0_col9, #T_9afa4_row1_col6, #T_9afa4_row1_col7, #T_9afa4_row1_col8, #T_9afa4_row1_col9, #T_9afa4_row2_col6, #T_9afa4_row2_col7, #T_9afa4_row2_col8, #T_9afa4_row2_col9, #T_9afa4_row3_col6, #T_9afa4_row3_col7, #T_9afa4_row3_col8, #T_9afa4_row3_col9, #T_9afa4_row4_col6, #T_9afa4_row4_col7, #T_9afa4_row4_col8, #T_9afa4_row4_col9, #T_9afa4_row5_col6, #T_9afa4_row5_col7, #T_9afa4_row5_col8, #T_9afa4_row5_col9, #T_9afa4_row6_col6, #T_9afa4_row6_col7, #T_9afa4_row6_col8, #T_9afa4_row6_col9, #T_9afa4_row7_col6, #T_9afa4_row7_col7, #T_9afa4_row7_col8, #T_9afa4_row7_col9, #T_9afa4_row8_col6, #T_9afa4_row8_col7, #T_9afa4_row8_col8, #T_9afa4_row8_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_9afa4_row0_col16, #T_9afa4_row0_col17, #T_9afa4_row0_col18, #T_9afa4_row0_col19, #T_9afa4_row0_col26, #T_9afa4_row0_col27, #T_9afa4_row0_col28, #T_9afa4_row0_col29, #T_9afa4_row1_col16, #T_9afa4_row1_col17, #T_9afa4_row1_col18, #T_9afa4_row1_col19, #T_9afa4_row4_col16, #T_9afa4_row4_col17, #T_9afa4_row4_col18, #T_9afa4_row4_col19, #T_9afa4_row4_col26, #T_9afa4_row4_col27, #T_9afa4_row4_col28, #T_9afa4_row4_col29, #T_9afa4_row6_col26, #T_9afa4_row6_col27, #T_9afa4_row6_col28, #T_9afa4_row6_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_9afa4_row1_col26, #T_9afa4_row1_col27, #T_9afa4_row1_col28, #T_9afa4_row1_col29, #T_9afa4_row3_col16, #T_9afa4_row3_col17, #T_9afa4_row3_col18, #T_9afa4_row3_col19, #T_9afa4_row3_col26, #T_9afa4_row3_col27, #T_9afa4_row3_col28, #T_9afa4_row3_col29, #T_9afa4_row6_col16, #T_9afa4_row6_col17, #T_9afa4_row6_col18, #T_9afa4_row6_col19 {
#   background-color: #c7e9c0;
#   color: black;
# }
# #T_9afa4_row5_col16, #T_9afa4_row5_col17, #T_9afa4_row5_col18, #T_9afa4_row5_col19, #T_9afa4_row5_col26, #T_9afa4_row5_col27, #T_9afa4_row5_col28, #T_9afa4_row5_col29 {
#   background-color: #31a354;
#   color: white;
# }
# #T_9afa4_row7_col16, #T_9afa4_row7_col17, #T_9afa4_row7_col18, #T_9afa4_row7_col19, #T_9afa4_row7_col26, #T_9afa4_row7_col27, #T_9afa4_row7_col28, #T_9afa4_row7_col29 {
#   background-color: #006d2c;
#   color: white;
# }
# </style>
# <table id="T_9afa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9afa4_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_9afa4_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_9afa4_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_9afa4_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_9afa4_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_9afa4_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_9afa4_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_9afa4_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_9afa4_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_9afa4_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_9afa4_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_9afa4_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_9afa4_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_9afa4_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_9afa4_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_9afa4_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_9afa4_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_9afa4_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_9afa4_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_9afa4_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_9afa4_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_9afa4_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_9afa4_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_9afa4_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_9afa4_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_9afa4_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_9afa4_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_9afa4_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_9afa4_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_9afa4_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_9afa4_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_9afa4_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_9afa4_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_9afa4_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_9afa4_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_9afa4_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_9afa4_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_9afa4_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_9afa4_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9afa4_level0_row0" class="row_heading level0 row0" >DeepSeek R1</th>
#       <td id="T_9afa4_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_9afa4_row0_col1" class="data row0 col1" >4.7</td>
#       <td id="T_9afa4_row0_col2" class="data row0 col2" >(1.2)</td>
#       <td id="T_9afa4_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_9afa4_row0_col4" class="data row0 col4" >1.7</td>
#       <td id="T_9afa4_row0_col5" class="data row0 col5" >(0.7)</td>
#       <td id="T_9afa4_row0_col6" class="data row0 col6" >-3.0</td>
#       <td id="T_9afa4_row0_col7" class="data row0 col7" >-64.4%</td>
#       <td id="T_9afa4_row0_col8" class="data row0 col8" >-16.18</td>
#       <td id="T_9afa4_row0_col9" class="dat

# %%
style_result(
    calc(
        df=competition_full_df[competition_full_df['variation_id'] == 'fully_rational'],
        group_columns=['model_type'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['confidence', 'bet_1', 'bet_avg']
    )
)
# Out:
# <style type="text/css">
# #T_b8f55 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_b8f55 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_b8f55 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_b8f55_row0_col6, #T_b8f55_row0_col7, #T_b8f55_row0_col8, #T_b8f55_row0_col9, #T_b8f55_row1_col6, #T_b8f55_row1_col7, #T_b8f55_row1_col8, #T_b8f55_row1_col9, #T_b8f55_row2_col6, #T_b8f55_row2_col7, #T_b8f55_row2_col8, #T_b8f55_row2_col9 {
#   background-color: #99000d;
#   color: white;
# }
# #T_b8f55_row0_col16, #T_b8f55_row0_col17, #T_b8f55_row0_col18, #T_b8f55_row0_col19 {
#   background-color: #74c476;
#   color: black;
# }
# #T_b8f55_row0_col26, #T_b8f55_row0_col27, #T_b8f55_row0_col28, #T_b8f55_row0_col29 {
#   background-color: #31a354;
#   color: white;
# }
# #T_b8f55_row1_col16, #T_b8f55_row1_col17, #T_b8f55_row1_col18, #T_b8f55_row1_col19, #T_b8f55_row1_col26, #T_b8f55_row1_col27, #T_b8f55_row1_col28, #T_b8f55_row1_col29 {
#   background-color: #f2f2f2;
#   color: #666666;
# }
# #T_b8f55_row2_col16, #T_b8f55_row2_col17, #T_b8f55_row2_col18, #T_b8f55_row2_col19, #T_b8f55_row2_col26, #T_b8f55_row2_col27, #T_b8f55_row2_col28, #T_b8f55_row2_col29 {
#   background-color: #006d2c;
#   color: white;
# }
# </style>
# <table id="T_b8f55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8f55_level0_col0" class="col_heading level0 col0" colspan="10">confidence</th>
#       <th id="T_b8f55_level0_col10" class="col_heading level0 col10" colspan="10">bet_1</th>
#       <th id="T_b8f55_level0_col20" class="col_heading level0 col20" colspan="10">bet_avg</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_b8f55_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_b8f55_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_b8f55_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_b8f55_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_b8f55_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_b8f55_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_b8f55_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_b8f55_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_b8f55_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_b8f55_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_b8f55_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_b8f55_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_b8f55_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_b8f55_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_b8f55_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_b8f55_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_b8f55_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_b8f55_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_b8f55_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_b8f55_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_b8f55_level2_col14" class="col_heading level2 col14" >Avg</th>
#       <th id="T_b8f55_level2_col15" class="col_heading level2 col15" >Std</th>
#       <th id="T_b8f55_level2_col16" class="col_heading level2 col16" >Diff</th>
#       <th id="T_b8f55_level2_col17" class="col_heading level2 col17" >R. Diff</th>
#       <th id="T_b8f55_level2_col18" class="col_heading level2 col18" >T-Stat</th>
#       <th id="T_b8f55_level2_col19" class="col_heading level2 col19" >P-Value</th>
#       <th id="T_b8f55_level2_col20" class="col_heading level2 col20" >N</th>
#       <th id="T_b8f55_level2_col21" class="col_heading level2 col21" >Avg</th>
#       <th id="T_b8f55_level2_col22" class="col_heading level2 col22" >Std</th>
#       <th id="T_b8f55_level2_col23" class="col_heading level2 col23" >N</th>
#       <th id="T_b8f55_level2_col24" class="col_heading level2 col24" >Avg</th>
#       <th id="T_b8f55_level2_col25" class="col_heading level2 col25" >Std</th>
#       <th id="T_b8f55_level2_col26" class="col_heading level2 col26" >Diff</th>
#       <th id="T_b8f55_level2_col27" class="col_heading level2 col27" >R. Diff</th>
#       <th id="T_b8f55_level2_col28" class="col_heading level2 col28" >T-Stat</th>
#       <th id="T_b8f55_level2_col29" class="col_heading level2 col29" >P-Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8f55_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_b8f55_row0_col0" class="data row0 col0" >162</td>
#       <td id="T_b8f55_row0_col1" class="data row0 col1" >5.5</td>
#       <td id="T_b8f55_row0_col2" class="data row0 col2" >(0.9)</td>
#       <td id="T_b8f55_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_b8f55_row0_col4" class="data row0 col4" >2.7</td>
#       <td id="T_b8f55_row0_col5" class="data row0 col5" >(1.6)</td>
#       <td id="T_b8f55_row0_col6" class="data row0 col6" >-2.8</td>
#       <td id="T_b8f55_row0_col7" class="data row0 col7" >-51.5%</td>
#       <td id="T_b8f55_row0_col8" class="data row0 col8" >-19.48</td>
#       <td id="T_b8f55_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_b8f55_row0_col10" class="data row0 col10" >162</td>
#       <td id="T_b8f55_row0_col11" class="data row0 col11" >3.5</td>
#       <td id="T_b8f55_row0_col12" class="data row0 col12" >(7.0)</td>
#       <td id="T_b8f55_row0_col13" class="data row0 col13" >162</td>
#       <td id="T_b8f55_row0_col14" class="data row0 col14" >5.7</td>
#       <td id="T_b8f55_row0_col15" class="data row0 col15" >(9.5)</td>
#       <td id="T_b8f55_row0_col16" class="data row0 col16" >2.2</td>
#       <td id="T_b8f55_row0_col17" class="data row0 col17" >62.5%</td>
#       <td id="T_b8f55_row0_col18" class="data row0 col18" >2.38</td>
#       <td id="T_b8f55_row0_col19" class="data row0 col19" >0.0179</td>
#       <td id="T_b8f55_row0_col20" class="data row0 col20" >162</td>
#       <td id="T_b8f55_row0_col21" class="data row0 col21" >4.6</td>
#       <td id="T_b8f55_row0_col22" class="data row0 col22" >(7.8)</td>
#       <td id="T_b8f55_row0_col23" class="data row0 col23" >162</td>
#       <td id="T_b8f55_row0_col24" class="data row0 col24" >7.5</td>
#       <td id="T_b8f55_row0_col25" class="data row0 col25" >(10.2)</td>
#       <td id="T_b8f55_row0
