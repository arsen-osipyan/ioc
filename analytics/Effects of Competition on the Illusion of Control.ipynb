# %% [markdown]
# # Effects of Competition on the Illusion of Control

# %%
from dotenv import load_dotenv
load_dotenv()

import os
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# ### Reading & Preparing Data

# %%
df = pd.read_csv('.' + os.environ.get('RESULTS_FOLDER') + 'competition_test/1774375251/results.csv')

# %%
df.isna().sum()
# Out:
# gender           0
# model_id         0
# bet_1            0
# bet_2            0
# bet_3            0
# bet_4            0
# confidence       0
# experiment_id    0
# variation_id     0
# condition_id     0
# iteration_id     0
# dtype: int64

# %%
df.loc[:, 'bet_avg'] = 0.25 * (df['bet_1'] + df['bet_2'] + df['bet_3'] + df['bet_4'])

# %% [markdown]
# ### Analysis

# %%
def group_function(
    group_df: pd.DataFrame,
    condition_column: str,
    condition_control: str,
    metric_columns: list[str]
):
    if condition_column not in group_df.columns:
        raise RuntimeError(f'Column {condition_column} is not found in group DataFrame.')
    if group_df[group_df[condition_column] == condition_control].empty:
        raise RuntimeError(f'Condition {condition_control} is not found in {condition_column} column.')

    result = dict()
    
    group_control_df = group_df[group_df[condition_column] == condition_control]
    
    for m in metric_columns:
        result[(condition_control, m, 'N')] = round(group_control_df[m].count())
        result[(condition_control, m, 'Avg')] = round(group_control_df[m].mean(), 1)
        result[(condition_control, m, 'Std')] = round(group_control_df[m].std(), 1)

    for c in group_df[condition_column].unique():
        if c == condition_control:
            continue
        
        group_condition_df = group_df[group_df[condition_column] == c]

        for m in metric_columns:
            result[(c, m, 'N')] = round(group_condition_df[m].count())
            result[(c, m, 'Avg')] = round(group_condition_df[m].mean(), 1)
            result[(c, m, 'Std')] = round(group_condition_df[m].std(), 1)
        
            diff = result[(c, m, 'Avg')] - result[(condition_control, m, 'Avg')]
            r_diff = result[(c, m, 'Avg')] / result[(condition_control, m, 'Avg')] if result[(condition_control, m, 'Avg')] != 0 else np.nan

            if result[(condition_control, m, 'N')] > 1 and result[(c, m, 'N')]:# > 1 and result[(condition_control, m, 'Std')] > 0 and result[(c, m, 'Std')] > 0:
                t_stat, p_value = stats.ttest_ind_from_stats(
                    mean1=result[(c, m, 'Avg')], std1=result[(c, m, 'Std')], nobs1=result[(c, m, 'N')],
                    mean2=result[(condition_control, m, 'Avg')], std2=result[(condition_control, m, 'Std')], nobs2=result[(condition_control, m, 'N')],
                    equal_var=False,
                )
            else:
                t_stat, p_value = np.nan, np.nan

            result[(c, m, 'Diff')] = round(diff, 1)
            result[(c, m, 'R. Diff')] = round(r_diff, 3)
            result[(c, m, 'T-Stat')] = round(t_stat, 2)
            result[(c, m, 'P-Value')] = round(p_value, 4)

    return pd.Series(result)


def calc(
    df: pd.DataFrame,
    group_columns: list[str],
    condition_column: str,
    condition_control: str,
    metric_columns: list[str]
):
    return df.groupby(by=group_columns).apply(
        lambda g_df: group_function(g_df, condition_column, condition_control, metric_columns),
        include_groups=False
    )

# %%
print(calc(
    df=df,
    group_columns=['experiment_id', 'variation_id', 'model_id'],
    condition_column='condition_id',
    condition_control='dapper',
    metric_columns=['bet_1']
))
print(calc(
    df=df,
    group_columns=['experiment_id', 'variation_id', 'model_id'],
    condition_column='condition_id',
    condition_control='dapper',
    metric_columns=['bet_avg']
))
print(calc(
    df=df,
    group_columns=['experiment_id', 'variation_id', 'model_id'],
    condition_column='condition_id',
    condition_control='dapper',
    metric_columns=['confidence']
))
# Out:
#                                           dapper            schnook        \
#                                            bet_1              bet_1
#                                                N   Avg  Std       N   Avg
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano   18.0  11.4  0.9    18.0  10.7
#               default          gpt_5_nano   18.0  11.8  1.1    18.0  10.4
#               fully_rational   gpt_5_nano   18.0   0.0  0.0    18.0   1.4
#               higher_emphasis  gpt_5_nano   18.0   9.0  5.6    18.0  11.5
#               lower_emphasis   gpt_5_nano   18.0  10.9  3.5    18.0  11.9
#               without_emphasis gpt_5_nano   18.0  10.8  2.3    18.0  11.2
#
#
#
#                                            Std Diff R. Diff T-Stat P-Value
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano  1.7 -0.7   0.939  -1.54  0.1348
#               default          gpt_5_nano  2.9 -1.4   0.881  -1.92  0.0687
#               fully_rational   gpt_5_nano  5.9  1.4     NaN   1.01  0.3282
#               higher_emphasis  gpt_5_nano  3.6  2.5   1.278   1.59  0.1220
#               lower_emphasis   gpt_5_nano  1.2  1.0   1.092   1.15  0.2645
#               without_emphasis gpt_5_nano  3.0  0.4   1.037   0.45  0.6565
#                                            dapper            schnook        \
#                                           bet_avg            bet_avg
#                                                 N   Avg  Std       N   Avg
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano    18.0   9.1  2.3    18.0  10.3
#               default          gpt_5_nano    18.0  10.2  3.7    18.0  10.1
#               fully_rational   gpt_5_nano    18.0   0.9  2.1    18.0   2.9
#               higher_emphasis  gpt_5_nano    18.0   9.7  4.0    18.0   9.4
#               lower_emphasis   gpt_5_nano    18.0   9.5  3.2    18.0  10.0
#               without_emphasis gpt_5_nano    18.0  10.3  2.6    18.0  12.0
#
#
#
#                                            Std Diff R. Diff T-Stat P-Value
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano  3.2  1.2   1.132   1.29  0.2060
#               default          gpt_5_nano  3.3 -0.1   0.990  -0.09  0.9323
#               fully_rational   gpt_5_nano  5.9  2.0   3.222   1.35  0.1897
#               higher_emphasis  gpt_5_nano  2.7 -0.3   0.969  -0.26  0.7938
#               lower_emphasis   gpt_5_nano  2.8  0.5   1.053   0.50  0.6211
#               without_emphasis gpt_5_nano  3.8  1.7   1.165   1.57  0.1277
#                                               dapper              schnook  \
#                                           confidence           confidence
#                                                    N  Avg  Std          N
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano       18.0  5.6  0.5       18.0
#               default          gpt_5_nano       18.0  5.7  0.5       18.0
#               fully_rational   gpt_5_nano       18.0  5.8  0.4       18.0
#               higher_emphasis  gpt_5_nano       18.0  5.7  0.5       18.0
#               lower_emphasis   gpt_5_nano       18.0  5.0  0.3       18.0
#               without_emphasis gpt_5_nano       18.0  5.7  0.6       18.0
#
#                                                                          \
#
#                                            Avg  Std Diff R. Diff T-Stat
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano  2.4  0.6 -3.2   0.429 -17.38
#               default          gpt_5_nano  2.6  0.8 -3.1   0.456 -13.94
#               fully_rational   gpt_5_nano  2.6  0.6 -3.2   0.448 -18.83
#               higher_emphasis  gpt_5_nano  2.3  0.6 -3.4   0.404 -18.47
#               lower_emphasis   gpt_5_nano  3.7  0.6 -1.3   0.740  -8.22
#               without_emphasis gpt_5_nano  2.5  0.7 -3.2   0.439 -14.73
#
#
#
#                                           P-Value
# experiment_id variation_id     model_id
# competition   bets_in_dollars  gpt_5_nano     0.0
#               default          gpt_5_nano     0.0
#               fully_rational   gpt_5_nano     0.0
#               higher_emphasis  gpt_5_nano     0.0
#               lower_emphasis   gpt_5_nano     0.0
#               without_emphasis gpt_5_nano     0.0
