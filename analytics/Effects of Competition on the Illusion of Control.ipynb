# %% [markdown]
# # Effects of Competition on the Illusion of Control

# %%
from dotenv import load_dotenv
load_dotenv()

import os
import numpy as np
import pandas as pd
from scipy import stats

try:
    from pandas.io.formats.style import Styler
except Exception:
    Styler = object

# %% [markdown]
# ### Reading & Preparing Data

# %%
df = pd.read_csv('.' + os.environ.get('RESULTS_FOLDER') + 'competition_cheap/2026-04-02T16:27:11/results.csv')

# %%
df.isna().sum()
# Out:
# gender           0
# model_id         0
# bet_1            0
# bet_2            0
# bet_3            0
# bet_4            0
# confidence       0
# experiment_id    0
# variation_id     0
# condition_id     0
# iteration_id     0
# dtype: int64

# %%
df.loc[:, 'bet_avg'] = 0.25 * (df['bet_1'] + df['bet_2'] + df['bet_3'] + df['bet_4'])

# %% [markdown]
# ### Analysis

# %%
def group_function(
    group_df: pd.DataFrame,
    condition_column: str,
    condition_control: str,
    metric_columns: list[str],
) -> pd.Series:
    if condition_column not in group_df.columns:
        raise RuntimeError(f'Column {condition_column} is not found in group DataFrame.')
    if group_df[group_df[condition_column] == condition_control].empty:
        raise RuntimeError(f'Condition {condition_control} is not found in {condition_column} column.')

    result = {}

    control_df = group_df[group_df[condition_column] == condition_control]
    control_stats = {}

    for metric in metric_columns:
        n = control_df[metric].count()
        avg = control_df[metric].mean()
        std = control_df[metric].std()

        control_stats[metric] = {'n': n, 'avg': avg, 'std': std}

        result[(metric, condition_control, 'N')] = int(n)
        result[(metric, condition_control, 'Avg')] = round(avg, 1) if pd.notna(avg) else np.nan
        result[(metric, condition_control, 'Std')] = round(std, 1) if pd.notna(std) else np.nan

    for condition in group_df[condition_column].dropna().unique():
        if condition == condition_control:
            continue

        condition_df = group_df[group_df[condition_column] == condition]

        for metric in metric_columns:
            n = condition_df[metric].count()
            avg = condition_df[metric].mean()
            std = condition_df[metric].std()

            result[(metric, condition, 'N')] = int(n)
            result[(metric, condition, 'Avg')] = round(avg, 1) if pd.notna(avg) else np.nan
            result[(metric, condition, 'Std')] = round(std, 1) if pd.notna(std) else np.nan

            control_avg = control_stats[metric]['avg']
            control_std = control_stats[metric]['std']
            control_n = control_stats[metric]['n']

            diff = avg - control_avg if pd.notna(avg) and pd.notna(control_avg) else np.nan
            r_diff = avg / control_avg if pd.notna(control_avg) and control_avg != 0 else np.nan

            if (
                pd.notna(avg)
                and pd.notna(std)
                and pd.notna(control_avg)
                and pd.notna(control_std)
                and n > 1
                and control_n > 1
            ):
                t_stat, p_value = stats.ttest_ind_from_stats(
                    mean1=avg,
                    std1=std,
                    nobs1=n,
                    mean2=control_avg,
                    std2=control_std,
                    nobs2=control_n,
                    equal_var=False,
                )
            else:
                t_stat, p_value = np.nan, np.nan

            result[(metric, condition, 'Diff')] = round(diff, 1) if pd.notna(diff) else np.nan
            result[(metric, condition, 'R. Diff')] = round(r_diff, 3) if pd.notna(r_diff) else np.nan
            result[(metric, condition, 'T-Stat')] = round(t_stat, 2) if pd.notna(t_stat) else np.nan
            result[(metric, condition, 'P-Value')] = round(p_value, 4) if pd.notna(p_value) else np.nan

    return pd.Series(result)

# %%
def _sort_metric_condition_stat_columns(
    df: pd.DataFrame,
    condition_control: str,
) -> pd.DataFrame:
    if not isinstance(df.columns, pd.MultiIndex):
        return df

    stats_order_control = ['N', 'Avg', 'Std']
    stats_order_test = ['N', 'Avg', 'Std', 'Diff', 'R. Diff', 'T-Stat', 'P-Value']

    metrics = list(dict.fromkeys(df.columns.get_level_values(0)))
    conditions = list(dict.fromkeys(df.columns.get_level_values(1)))

    ordered_cols = []

    for metric in metrics:
        if condition_control in conditions:
            for stat in stats_order_control:
                col = (metric, condition_control, stat)
                if col in df.columns:
                    ordered_cols.append(col)

        for condition in conditions:
            if condition == condition_control:
                continue
            for stat in stats_order_test:
                col = (metric, condition, stat)
                if col in df.columns:
                    ordered_cols.append(col)

    remaining = [col for col in df.columns if col not in ordered_cols]
    ordered_cols.extend(remaining)

    return df.loc[:, ordered_cols]

# %%
def calc(
    df: pd.DataFrame,
    group_columns: list[str],
    condition_column: str,
    condition_control: str,
    metric_columns: list[str],
) -> pd.DataFrame:
    result = df.groupby(by=group_columns).apply(
        lambda g_df: group_function(g_df, condition_column, condition_control, metric_columns),
        include_groups=False,
    )

    result.columns = pd.MultiIndex.from_tuples(result.columns)
    result = _sort_metric_condition_stat_columns(result, condition_control=condition_control)

    return result

# %%
def _pvalue_to_style(p_value: float, positive_effect: bool) -> str:
    if pd.isna(p_value):
        return ''

    if positive_effect:
        if p_value < 0.001:
            return 'background-color: #006d2c; color: white;'
        elif p_value < 0.01:
            return 'background-color: #31a354; color: white;'
        elif p_value < 0.05:
            return 'background-color: #74c476; color: black;'
        elif p_value < 0.10:
            return 'background-color: #c7e9c0; color: black;'
        else:
            return ''
    else:
        if p_value < 0.001:
            return 'background-color: #99000d; color: white;'
        elif p_value < 0.01:
            return 'background-color: #cb181d; color: white;'
        elif p_value < 0.05:
            return 'background-color: #fb6a4a; color: black;'
        elif p_value < 0.10:
            return 'background-color: #fcbba1; color: black;'
        else:
            return ''

# %%
def highlight_significance_gradient(
    df: pd.DataFrame,
    alpha: float = 0.10,
    stats_to_color: tuple[str, ...] = ('Diff', 'R. Diff', 'T-Stat', 'P-Value'),
    nonsig_style: str = 'background-color: #f2f2f2; color: #666666;',
) -> pd.DataFrame:
    '''
    Ожидает колонки вида: (metric, condition, stat)

    Логика:
    - p < alpha и Diff > 0  -> зеленый оттенок
    - p < alpha и Diff < 0  -> красный оттенок
    - p >= alpha            -> светло-серый
    '''
    styles = pd.DataFrame('', index=df.index, columns=df.columns)

    if not isinstance(df.columns, pd.MultiIndex):
        return styles

    metrics = df.columns.get_level_values(0).unique()
    conditions = df.columns.get_level_values(1).unique()

    for metric in metrics:
        for condition in conditions:
            p_col = (metric, condition, 'P-Value')
            diff_col = (metric, condition, 'Diff')

            if p_col not in df.columns or diff_col not in df.columns:
                continue

            for idx in df.index:
                pval = df.at[idx, p_col]
                diff = df.at[idx, diff_col]

                if pd.isna(pval) or pd.isna(diff):
                    continue

                if pval < alpha and diff != 0:
                    style = _pvalue_to_style(pval, positive_effect=(diff > 0))
                else:
                    style = nonsig_style

                for stat_name in stats_to_color:
                    col = (metric, condition, stat_name)
                    if col in df.columns:
                        styles.at[idx, col] = style

    return styles

# %%
def style_result(
    result_df: pd.DataFrame,
    alpha: float = 0.10,
):
    format_dict = {}

    for col in result_df.columns:
        stat = col[2]
        if stat == 'N':
            format_dict[col] = '{:.0f}'
        elif stat in ('Avg', 'Std', 'Diff'):
            format_dict[col] = '{:.1f}'
        elif stat == 'R. Diff':
            format_dict[col] = '{:.3f}'
        elif stat == 'T-Stat':
            format_dict[col] = '{:.2f}'
        elif stat == 'P-Value':
            format_dict[col] = '{:.4f}'

    table_styles = [
        {
            'selector': 'table',
            'props': [
                ('width', 'auto'),
                ('table-layout', 'auto'),
                ('border-collapse', 'collapse'),
            ],
        },
        {
            'selector': 'th',
            'props': [
                ('white-space', 'nowrap'),
                ('word-break', 'keep-all'),
                ('overflow-wrap', 'normal'),
                ('text-align', 'left'),
            ],
        },
        {
            'selector': 'td',
            'props': [
                ('white-space', 'nowrap'),
                ('word-break', 'keep-all'),
                ('overflow-wrap', 'normal'),
            ],
        },
    ]

    return (
        result_df.style
        .apply(highlight_significance_gradient, axis=None, alpha=alpha)
        .format(format_dict, na_rep='—')
        .set_table_styles(table_styles)
    )

# %%
style_result(
    calc(
        df=df,
        group_columns=['experiment_id', 'variation_id', 'model_id', 'iteration_id'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['bet_1', 'bet_2', 'bet_3', 'bet_4', 'bet_avg', 'confidence']
    )
)
# Out:
# <style type="text/css">
# #T_3a4f4 table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_3a4f4 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_3a4f4 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_3a4f4_row0_col6, #T_3a4f4_row0_col7, #T_3a4f4_row0_col8, #T_3a4f4_row0_col9, #T_3a4f4_row0_col16, #T_3a4f4_row0_col17, #T_3a4f4_row0_col18, #T_3a4f4_row0_col19, #T_3a4f4_row0_col36, #T_3a4f4_row0_col37, #T_3a4f4_row0_col38, #T_3a4f4_row0_col39, #T_3a4f4_row1_col16, #T_3a4f4_row1_col17, #T_3a4f4_row1_col18, #T_3a4f4_row1_col19, #T_3a4f4_row1_col26, #T_3a4f4_row1_col27, #T_3a4f4_row1_col28, #T_3a4f4_row1_col29, #T_3a4f4_row1_col36, #T_3a4f4_row1_col37, #T_3a4f4_row1_col38, #T_3a4f4_row1_col39, #T_3a4f4_row1_col46, #T_3a4f4_row1_col47, #T_3a4f4_row1_col48, #T_3a4f4_row1_col49, #T_3a4f4_row2_col6, #T_3a4f4_row2_col7, #T_3a4f4_row2_col8, #T_3a4f4_row2_col9, #T_3a4f4_row2_col16, #T_3a4f4_row2_col17, #T_3a4f4_row2_col18, #T_3a4f4_row2_col19, #T_3a4f4_row2_col26, #T_3a4f4_row2_col27, #T_3a4f4_row2_col28, #T_3a4f4_row2_col29, #T_3a4f4_row2_col36, #T_3a4f4_row2_col37, #T_3a4f4_row2_col38, #T_3a4f4_row2_col39, #T_3a4f4_row2_col46, #T_3a4f4_row2_col47, #T_3a4f4_row2_col48, #T_3a4f4_row2_col49, #T_3a4f4_row3_col6, #T_3a4f4_row3_col7, #T_3a4f4_row3_col8, #T_3a4f4_row3_col9, #T_3a4f4_row3_col16, #T_3a4f4_row3_col17, #T_3a4f4_row3_col18, #T_3a4f4_row3_col19, #T_3a4f4_row3_col26, #T_3a4f4_row3_col27, #T_3a4f4_row3_col28, #T_3a4f4_row3_col29, #T_3a4f4_row3_col36, #T_3a4f4_row3_col37, #T_3a4f4_row3_col38, #T_3a4f4_row3_col39, #T_3a4f4_row3_col46, #T_3a4f4_row3_col47, #T_3a4f4_row3_col48, #T_3a4f4_row3_col49, #T_3a4f4_row4_col6, #T_3a4f4_row4_col7, #T_3a4f4_row4_col8, #T_3a4f4_row4_col9, #T_3a4f4_row4_col16, #T_3a4f4_row4_col17, #T_3a4f4_row4_col18, #T_3a4f4_row4_col19, #T_3a4f4_row4_col26, #T_3a4f4_row4_col27, #T_3a4f4_row4_col28, #T_3a4f4_row4_col29, #T_3a4f4_row4_col36, #T_3a4f4_row4_col37, #T_3a4f4_row4_col38, #T_3a4f4_row4_col39, #T_3a4f4_row4_col46, #T_3a4f4_row4_col47, #T_3a4f4_row4_col48, #T_3a4f4_row4_col49, #T_3a4f4_row5_col6, #T_3a4f4_row5_col7, #T_3a4f4_row5_col8, #T_3a4f4_row5_col9, #T_3a4f4_row5_col26, #T_3a4f4_row5_col27, #T_3a4f4_row5_col28, #T_3a4f4_row5_col29, #T_3a4f4_row5_col36, #T_3a4f4_row5_col37, #T_3a4f4_row5_col38, #T_3a4f4_row5_col39, #T_3a4f4_row6_col36, #T_3a4f4_row6_col37, #T_3a4f4_row6_col38, #T_3a4f4_row6_col39, #T_3a4f4_row7_col6, #T_3a4f4_row7_col7, #T_3a4f4_row7_col8, #T_3a4f4_row7_col9, #T_3a4f4_row7_col16, #T_3a4f4_row7_col17, #T_3a4f4_row7_col18, #T_3a4f4_row7_col19, #T_3a4f4_row7_col26, #T_3a4f4_row7_col27, #T_3a4f4_row7_col28, #T_3a4f4_row7_col29, #T_3a4f4_row7_col36, #T_3a4f4_row7_col37, #T_3a4f4_row7_col38, #T_3a4f4_row7_col39, #T_3a4f4_row7_col46, #T_3a4f4_row7_col47, #T_3a4f4_row7_col48, #T_3a4f4_row7_col49, #T_3a4f4_row8_col16, #T_3a4f4_row8_col17, #T_3a4f4_row8_col18, #T_3a4f4_row8_col19, #T_3a4f4_row8_col26, #T_3a4f4_row8_col27, #T_3a4f4_row8_col28, #T_3a4f4_row8_col29, #T_3a4f4_row8_col36, #T_3a4f4_row8_col37, #T_3a4f4_row8_col38, #T_3a4f4_row8_col39, #T_3a4f4_row8_col46, #T_3a4f4_row8_col47, #T_3a4f4_row8_col48, #T_3a4f4_row8_col49, #T_3a4f4_row12_col6, #T_3a4f4_row12_col7, #T_3a4f4_row12_col8, #T_3a4f4_row12_col9, #T_3a4f4_row12_col16, #T_3a4f4_row12_col17, #T_3a4f4_row12_col18, #T_3a4f4_row12_col19, #T_3a4f4_row12_col26, #T_3a4f4_row12_col27, #T_3a4f4_row12_col28, #T_3a4f4_row12_col29, #T_3a4f4_row12_col36, #T_3a4f4_row12_col37, #T_3a4f4_row12_col38, #T_3a4f4_row12_col39, #T_3a4f4_row12_col46, #T_3a4f4_row12_col47, #T_3a4f4_row12_col48, #T_3a4f4_row12_col49, #T_3a4f4_row13_col6, #T_3a4f4_row13_col7, #T_3a4f4_row13_col8, #T_3a4f4_row13_col9, #T_3a4f4_row13_col16, #T_3a4f4_row13_col17, #T_3a4f4_row13_col18, #T_3a4f4_row13_col19, #T_3a4f4_row13_col26, #T_3a4f4_row13_col27, #T_3a4f4_row13_col28, #T_3a4f4_row13_col29, #T_3a4f4_row13_col36, #T_3a4f4_row13_col37, #T_3a4f4_row13_col38, #T_3a4f4_row13_col39, #T_3a4f4_row13_col46, #T_3a4f4_row13_col47, #T_3a4f4_row13_col48, #T_3a4f4_row13_col49, #T_3a4f4_row14_col6, #T_3a4f4_row14_col7, #T_3a4f4_row14_col8, #T_3a4f4_row14_col9, #T_3a4f4_row14_col16, #T_3a4f4_row14_col17, #T_3a4f4_row14_col18, #T_3a4f4_row14_col19, #T_3a4f4_row14_col26, #T_3a4f4_row14_col ...

# %%
style_result(
    calc(
        df=df,
        group_columns=['experiment_id', 'model_id', 'variation_id'],
        condition_column='condition_id',
        condition_control='dapper',
        metric_columns=['bet_1', 'bet_2', 'bet_3', 'bet_4', 'bet_avg', 'confidence']
    )
)
# Out:
# <style type="text/css">
# #T_f69eb table {
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_f69eb th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_f69eb td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_f69eb_row0_col6, #T_f69eb_row0_col7, #T_f69eb_row0_col8, #T_f69eb_row0_col9, #T_f69eb_row13_col36, #T_f69eb_row13_col37, #T_f69eb_row13_col38, #T_f69eb_row13_col39 {
#   background-color: #fcbba1;
#   color: black;
# }
# #T_f69eb_row0_col16, #T_f69eb_row0_col17, #T_f69eb_row0_col18, #T_f69eb_row0_col19, #T_f69eb_row0_col26, #T_f69eb_row0_col27, #T_f69eb_row0_col28, #T_f69eb_row0_col29, #T_f69eb_row0_col46, #T_f69eb_row0_col47, #T_f69eb_row0_col48, #T_f69eb_row0_col49, #T_f69eb_row1_col6, #T_f69eb_row1_col7, #T_f69eb_row1_col8, #T_f69eb_row1_col9, #T_f69eb_row1_col16, #T_f69eb_row1_col17, #T_f69eb_row1_col18, #T_f69eb_row1_col19, #T_f69eb_row1_col26, #T_f69eb_row1_col27, #T_f69eb_row1_col28, #T_f69eb_row1_col29, #T_f69eb_row1_col36, #T_f69eb_row1_col37, #T_f69eb_row1_col38, #T_f69eb_row1_col39, #T_f69eb_row1_col46, #T_f69eb_row1_col47, #T_f69eb_row1_col48, #T_f69eb_row1_col49, #T_f69eb_row2_col6, #T_f69eb_row2_col7, #T_f69eb_row2_col8, #T_f69eb_row2_col9, #T_f69eb_row3_col26, #T_f69eb_row3_col27, #T_f69eb_row3_col28, #T_f69eb_row3_col29, #T_f69eb_row
#   width: auto;
#   table-layout: auto;
#   border-collapse: collapse;
# }
# #T_3f7b2 th {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
#   text-align: left;
# }
# #T_3f7b2 td {
#   white-space: nowrap;
#   word-break: keep-all;
#   overflow-wrap: normal;
# }
# #T_3f7b2_row0_col6, #T_3f7b2_row0_col7, #T_3f7b2_row0_col8, #T_3f7b2_row0_col9 {
#   background-color: #fcbba1;
#   color: black;
# }
# #T_3f7b2_row0_col16, #T_3f7b2_row0_col17, #T_3f7b2_row0_col18, #T_3f7b2_row0_col19, #T_3f7b2_row1_col6, #T_3f7b2_row1_col7, #T_3f7b2_row1_col8, #T_3f7b2_row1_col9, #T_3f7b2_row1_col16, #T_3f7b2_row1_col17, #T_3f7b2_row1_col18, #T_3f7b2_row1_col19, #T_3f7b2_row2_col6, #T_3f7b2_row2_col7, #T_3f7b2_row2_col8, #T_3f7b2_row2_col9, #T_3f7b2_row3_col16, #T_3f7b2_row3_col17, #T_3f7b2_row3_col18, #T_3f7b2_row3_col19, #T_3f7b2_row4_col6, #T_3f7b2_row4_col7, #T_3f7b2_row4_col8, #T_3f7b2_row4_col9, #T_3f7b2_row4_col16, #T_3f7b2_row4_col17, #T_3f7b2_row4_col18, #T_3f7b2_row4_col19, #T_3f7b2_row5_col6, #T_3f7b2_row5_col7, #T_3f7b2_row5_col8, #T_3f7b2_row5_col9, #T_3f7b2_row5_col16, #T_3f7b2_row5_col17, #T_3f7b2_row5_col18, #T_3f7b2_row5_col19, #T_3f7b2_row5_col26, #T_3f7b2_row5_col27, #T_3f7b2_row5_col28, #T_3f7b2_row5_col29, #T_3f7b2_row6_col6, #T_3f7b2_row6_col7, #T_3f7b2_row6_col8, #T_3f7b2_row6_col9, #T_3f7b2_row6_col16, #T_3f7b2_row6_col17, #T_3f7b2_row6_col18, #T_3f7b2_row6_col19, #T_3f7b2_row7_col6, #T_3f7b2_row7_col7, #T_3f7b2_row7_col8, #T_3f7b2_row7_col9, #T_3f7b2_row7_col16, #T_3f7b2_row7_col17, #T_3f7b2_row7_col18, #T_3f7b2_row7_col19, #T_3f7b2_row8_col6, #T_3f7b2_row8_col7, #T_3f7b2_row8_col8, #T_3f7b2_row8_col9, #T_3f7b2_row9_col16, #T_3f7b2_row9_col17, #T_3f7b2_row9_col18, #T_3f7b2_row9_col19, #T_3f7b2_row10_col6, #T_3f7b2_row10_col7, #T_3f7b2_row10_col8, #T_3f7b2_row10_col9, #T_3f7b2_row10_col16, #T_3f7b2_row10_col17, #T_3f7b2_row10_col18, #T_3f7b2_row10_col19, #T_3f7b2_row11_col6, #T_3f7b2_row11_col7, #T_3f7b2_row11_col8, #T_3f7b2_row11_col9, #T_3f7b2_row11_col16, #T_3f7b2_row11_col17, #T_3f7b2_row11_col18, #T_3f7b2_row11_col19, #T_3f7b2_row11_col26, #T_3f7b2_row11_col27, #T_3f7b2_row11_col28, #T_3f7b2_row11_col29, #T_3f7b2_row13_col16, #T_3f7b2_row13_col17, #T_3f7b2_row13_col18, #T_3f7b2_row13_col19, #T_3f7b2_row14_col6, #T_3f7
#   background-color: #99000d;
#   color: white;
# }
# #T_3f7b2_row2_col16, #T_3f7b2_row2_col17, #T_3f7b2_row2_col18, #T_3f7b2_row2_col19, #T_3f7b2_row9_col6, #T_3f7b2_row9_col7, #T_3f7b2_row9_col8, #T_3f7b2_row9_col9, #T_3f7b2_row13_col6, #T_3f7b2_row13_col7, #T_3f7b2_row13_col8, #T_3f7b2_row13_col9, #T_3f7b2_row15_col6, #T_3f7b2_row15_col7, #T_3f7b2_row15_col8, #T_3f7b2_row15_col9 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_3f7b2_row3_col6, #T_3f7b2_row3_col7, #T_3f7b2_row3_col8, #T_3f7b2_row3_col9, #T_3f7b2_row8_col16, #T_3f7b2_row8_col17, #T_3f7b2_row8_col18, #T_3f7b2_row8_col19, #T_3f7b2_row12_col16, #T_3f7b2_row12_col17, #T_3f7b2_row12_col18, #T_3f7b2_row12_col19 {
#   background-color: #74c476;
#   color: black;
# }
# #T_3f7b2_row12_col6, #T_3f7b2_row12_col7, #T_3f7b2_row12_col8, #T_3f7b2_row12_col9 {
#   background-color: #31a354;
#   color: white;
# }
# </style>
# <table id="T_3f7b2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f7b2_level0_col0" class="col_heading level0 col0" colspan="10">bet_1</th>
#       <th id="T_3f7b2_level0_col10" class="col_heading level0 col10" colspan="10">bet_avg</th>
#       <th id="T_3f7b2_level0_col20" class="col_heading level0 col20" colspan="10">confidence</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_3f7b2_level1_col0" class="col_heading level1 col0" colspan="3">dapper</th>
#       <th id="T_3f7b2_level1_col3" class="col_heading level1 col3" colspan="7">schnook</th>
#       <th id="T_3f7b2_level1_col10" class="col_heading level1 col10" colspan="3">dapper</th>
#       <th id="T_3f7b2_level1_col13" class="col_heading level1 col13" colspan="7">schnook</th>
#       <th id="T_3f7b2_level1_col20" class="col_heading level1 col20" colspan="3">dapper</th>
#       <th id="T_3f7b2_level1_col23" class="col_heading level1 col23" colspan="7">schnook</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_3f7b2_level2_col0" class="col_heading level2 col0" >N</th>
#       <th id="T_3f7b2_level2_col1" class="col_heading level2 col1" >Avg</th>
#       <th id="T_3f7b2_level2_col2" class="col_heading level2 col2" >Std</th>
#       <th id="T_3f7b2_level2_col3" class="col_heading level2 col3" >N</th>
#       <th id="T_3f7b2_level2_col4" class="col_heading level2 col4" >Avg</th>
#       <th id="T_3f7b2_level2_col5" class="col_heading level2 col5" >Std</th>
#       <th id="T_3f7b2_level2_col6" class="col_heading level2 col6" >Diff</th>
#       <th id="T_3f7b2_level2_col7" class="col_heading level2 col7" >R. Diff</th>
#       <th id="T_3f7b2_level2_col8" class="col_heading level2 col8" >T-Stat</th>
#       <th id="T_3f7b2_level2_col9" class="col_heading level2 col9" >P-Value</th>
#       <th id="T_3f7b2_level2_col10" class="col_heading level2 col10" >N</th>
#       <th id="T_3f7b2_level2_col11" class="col_heading level2 col11" >Avg</th>
#       <th id="T_3f7b2_level2_col12" class="col_heading level2 col12" >Std</th>
#       <th id="T_3f7b2_level2_col13" class="col_heading level2 col13" >N</th>
#       <th id="T_3f7b2_level2_col1

# %%
import re

file_path = '../qwen_debug'

with open(file_path, 'r', encoding='utf-8') as f:
    content = f.read()

matches = re.findall(r'<response>(.*?)</response>', content, flags=re.DOTALL)

for part in matches:
    print(part)
# Out:
# 25 cents.
# [Mr. X is likely to bet the maximum amount to engage fully in the experiment, as he is an undergraduate participating for course credit and a chance to win money.]
# 25 cents.
# [Mr. X continues to bet the maximum to maintain engagement and maximize potential reward.]
# 25 cents.
# [Mr. X maintains maximum bet to stay engaged and maximize potential reward throughout the task.]
# 25 cents.
# [Mr. X continues to bet the maximum amount, indicating consistent engagement and desire to maximize potential gains.]
# 6.
# [Mr. X was impressed by Subject's confident and outgoing demeanor, leading him to rate Subject highly on competence.]
# 25.
# [Mr. X is likely to bet the maximum amount to maximize potential gain, reflecting a risk-seeking behavior common in experiments involving monetary incentives.]
# 25.
# [Mr. X continues to bet the maximum amount, maintaining consistent risk-seeking behavior throughout the task.]
# 25.
# [Mr. X maintains maximum bet to sustain engagement and maximize potential reward.]
# 25.
# [Mr. X persists with maximum bet, indicating consistent risk-taking behavior throughout the experiment.]
# 3.
# [Mr. X's awkward interaction with Subject suggests he perceived Subject as average in competence, neither particularly skilled nor incompetent.]
# 25 (Subject appears confident and is likely to bet high)
# 25 (Subject appears confident and is likely to bet high)
# 25 (Subject appears confident and is likely to bet high)
# 25 (Subject appears confident and is likely to bet high)
# 6 (Subject appeared confident and competent)
# 25
# Why: The user is asking for a specific number between 0 and 25, and "25" is a valid choice.
# 25
# Why: The user is asking for a specific number between 0 and 25, and "25" is a valid choice.
# 25
# Why: The user is asking for a specific number between 0 and 25, and "25" is a valid choice.
# 25
# Why: The user is asking for a specific number between 0 and 25, and "25" is a valid choice.
# 6
# Why: The user is asking for a specific number between 1 and 6, and "6" is a valid choice.
# 25 cents.
# [Mr. X is an undergraduate participating for course credit and a chance to win money, so he is likely to bet the maximum amount to maximize potential gain.]
# 25 cents.
# [Mr. X is motivated to maximize potential gains and has no reason to bet less.]
# 25 cents.
# [Mr. X continues to maximize his potential gain in each round.]
# 25 cents.
# [Mr. X's consistent behavior suggests a strategy to maximize potential rewards.]
# 6.
# [Subject appeared highly competent and confident, leading Mr. X to rate him as the highest.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is likely to bet the maximum amount to maximize potential gains, as he has no reason to believe the task is rigged or dangerous.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is likely to bet the maximum amount to maximize potential gains, as he has no reason to believe the task is rigged or dangerous.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is likely to bet the maximum amount to maximize potential gains, as he has no reason to believe the task is rigged or dangerous.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is likely to bet the maximum amount to maximize potential gains, as he has no reason to believe the task is rigged or dangerous.]
# 3 (from 1 to 6).
# [Mr. X observed Subject's nervousness and inexperience, but did not have enough information to rate him as extremely incompetent or competent.]
# 25 cents.
# [Mr. X is an undergraduate and may be eager to participate, possibly betting the maximum to maximize potential reward.]
# 25 cents.
# [Mr. X continues to bet the maximum, showing consistent willingness to take risks for potential reward.]
# 25 cents.
# [Mr. X maintains maximum bet, indicating consistent risk-taking behavior throughout the task.]
# 25 cents.
# [Mr. X consistently bets the maximum, showing sustained engagement and risk tolerance.]
# 6.
# [Mr. X consistently bet 25 cents, indicating high confidence in his abilities.]
# 25.
# [Mr. X is likely to bet the maximum to maximize potential gain, as the instructions mention winning or losing money and the task is framed as a game.]
# 25.
# [Mr. X is likely to bet the maximum to maximize potential gain, as the instructions mention winning or losing money and the task is framed as a game.]
# 25.
# [Mr. X is likely to bet the maximum to maximize potential gain, as the instructions mention winning or losing money and the task is framed as a game.]
# 25.
# [Mr. X is likely to bet the maximum to maximize potential gain, as the instructions mention winning or losing money and the task is framed as a game.]
# 6.
# [Mr. X observed Subject's behavior and may have rated them highly due to their apparent confidence or participation in the study.]
# 25 dollars (from 0 to 25 dollars).
# [Mr. X is an undergraduate and may be eager to participate, possibly betting the maximum to show commitment or due to inexperience.]
# 25 dollars (from 0 to 25 dollars).
# [Mr. X's initial bet was 25, indicating a consistent pattern of maximum risk-taking.]
# 25 dollars (from 0 to 25 dollars).
# [Mr. X maintains the same bet, showing consistent behavior.]
# 25 dollars (from 0 to 25 dollars).
# [Mr. X continues to bet the maximum, showing no change in behavior.]
# 6 (from 1 to 6).
# [Mr. X was impressed by Subject's confident and outgoing manner.]
# 25 dollars.
# [Mr. X is complying with the experiment's instructions and aiming to maximize potential winnings by betting the maximum amount allowed.]
# 25 dollars.
# [Mr. X is consistently betting the maximum amount, indicating confidence or a strategic approach to maximize potential gains.]
# 25 dollars.
# [Mr. X maintains a consistent betting strategy, reinforcing the pattern of maximum bets to maximize potential rewards.]
# 25 dollars.
# [Mr. X continues the pattern of maximum betting, showing consistent behavior throughout the task.]
# 3.
# [Mr. X perceives Subject as average, reflecting the subject's awkward and nervous behavior during the interaction.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is a fully rational economic agent and would bet the maximum to maximize potential gains.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is a fully rational economic agent and would bet the maximum to maximize potential gains.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is a fully rational economic agent and would bet the maximum to maximize potential gains.]
# 25 cents (from 0 to 25 cents).
# [Mr. X is a fully rational economic agent and would bet the maximum to maximize potential gains.]
# 6 (from 1 to 6).
# [Mr. X is a fully rational economic agent and would rate the confident, well-dressed subject highly.]
# 25 cents.
# [Mr. X is a fully rational economic agent and would maximize his potential gain by betting the maximum amount allowed, 25 cents, assuming he believes he has a chance to win.]
# 25 cents.
# [Mr. X is a fully rational economic agent and would maximize his potential gain by betting the maximum amount allowed, 25 cents, assuming he believes he has a chance to win.]
# 25 cents.
# [Mr. X is a fully rational economic agent and would maximize his potential gain by betting the maximum amount allowed, 25 cents, assuming he believes he has a chance to win.]
# 25 cents.
# [Mr. X is a fully rational economic agent and would maximize his potential gain by betting the maximum amount allowed, 25 cents, assuming he believes he has a chance to win.]
# 3.
# [Mr. X is a fully rational economic agent and would rate Subject's competence as average, given the limited interaction and Subject's timid behavior.]
